# %% [markdown]
# ### Task 1: Import Modules

# %%
from pytube import extract
from heapq import nlargest
from youtube_transcript_api import YouTubeTranscriptApi
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %% [markdown]
# ### Task 2: Get ID of the Youtube Video

# %%
url = 'https://www.youtube.com/watch?v=iXCmoQDEoe4'
video_id = extract.video_id(url)
video_id
# Out:
# 'iXCmoQDEoe4'

# %% [markdown]
# ### Task 3: Get Transcript of Video

# %%
transcript = YouTubeTranscriptApi.get_transcript(video_id)
text = ""
for elem in transcript:
    text = text + " " + elem["text"]
text
# Out:
# " Transcriber: Reihaneh Iranmanesh\nReviewer: Elisabeth Buffard When most people think about AI, they picture a sci-fi dystopian future,\nwith man versus machine. Terminator, Skynet, Black Mirror,\nBlade Runner, Westworld. But as someone who is working on the most ambitious\nAI projects in the world, every day, I can tell you\nthat is far from reality. To me, it’s the contrary of that. AI enhances\nand even supercharges humanity. Let me explain why. There are many reasons\nwhy AI will never replace humans. AI always has,\nand always will, rely on humans. That’s one of the reasons that I was actually inspired\nto start an AI company. That and my background\nhave had a huge impact on me and why I started Scale. My parents were brilliant scientists\nof Los Alamos, who accomplished a lot\nin advancing their field. That inspired me to use\nscience and technology to have a real impact on the world. My dad was a physicist,\nand my mom was an astrophysicist, both at the top of their field, who made meaningful contributions\nto plasma fluid dynamics and the beginnings of the universe. Their scientific work will have \nmeaningful impact on how we understand\nand perceive our world. And I wanted to work\non something as impactful or even more impactful than that. That’s why I decide\nto become a programmer, so I can make a difference in the world. Growing up as a programmer, despite how powerful computers are, you quickly realize\nhow limited they are. In particular, they lack\njudgment and intelligence. Programming is the art\nof giving clear robotic instructions to computers to accomplish\nsimple objectives. It’s all black and white,\nand there’s no gray area. As I learned about AI,\nit was clearly transformational. It changed the game. It equipped computers with intelligence,\nand I knew I wanted to be deeply involved. I was studying AI at MIT and slowly \nbecame more and more excited about all the potential applications of AI\nfor solving more nuanced problems. For example, there was one class project where I worked on applying AI \nto human emotions. The goal was to take picture\nof human expressions and ultimately identify and understand\nthe emotion through very subtle signals in facial expressions. Using AI, we built an algorithm that was able to detect intent\nwith 80% accuracy and efficacy. We were extremely proud of that. It was the start of using AI to do\nentirely new things using computers. That’s when I realize\nthe implications of AI and how it could tackle the gray areas\nthat involve judgment or intelligence. You see, AI needs humans\nto teach it individual values, nudge it to find thoughtful outcomes, and ensure that human intentions\nand values are aligned with the AI. It was a revelation. Before, coding was like\na black-and-white film versus watching in technicolor. What’s more, AI has the potential\nto take away the repetition in our lives, meaning that new and fresh ideas\nwill matter more and ultimately enable us to be more human. But, to power AI,\nyou need powerful data, which was especially hard to come by\nat that time, in 2016, while I was at MIT. I realized that nobody was building\nanything with AI outside of school. It’s unusual for MIT students\nto not be building something. Mechanical engineering majors\nare building catapults in the lawn, electrical engineering majors \nare building robots, and computer science majors are building\napps for their friends to use. But nobody was building\nanything using AI. That’s when I discovered what\na bottleneck data can be to building meaningful\nand powerful AI systems. You can't treat data as an afterthought. Bad data or lack of data\nresults in bad AI. I even realize this in my personal life. I put a camera inside my fridge\nto gather data, to tell me when to refill my groceries\nand what I needed to buy. That’s when I realized\njust how much data I needed to actually be able\nto successfully predict what to purchase. There’s no way I could create enough data to ...

# %% [markdown]
# ### Task 4: Get all Sentences

# %%
nlp = spacy.load('en_core_web_sm')
document = nlp(text)
for sentence in document.sents:
    print(sentence.text)
# Out:
#  Transcriber: Reihaneh Iranmanesh
# Reviewer: Elisabeth Buffard
# When most people think about AI, they picture a sci-fi dystopian future,
# with man versus machine.
# Terminator, Skynet, Black Mirror,
# Blade Runner, Westworld.
# But as someone who is working on the most ambitious
# AI projects in the world, every day, I can tell you
# that is far from reality.
# To me, it’s the contrary of that.
# AI enhances
# and even supercharges humanity.
# Let me explain why.
# There are many reasons
# why AI will never replace humans.
# AI always has,
# and always will, rely on humans.
# That’s one of the reasons that I was actually inspired
# to start an AI company.
# That and my background
# have had a huge impact on me and why I started Scale.
# My parents were brilliant scientists
# of Los Alamos, who accomplished a lot
# in advancing their field.
# That inspired me to use
# science and technology to have a real impact on the world.
# My dad was a physicist,
# and my mom was an astrophysicist, both at the top of their field, who made meaningful contributions
# to plasma fluid dynamics and the beginnings of the universe.
# Their scientific work will have
# meaningful impact on how we understand
# and perceive our world.
# And I wanted to work
# on something as impactful or even more impactful than that.
# That’s why I decide
# to become a programmer, so I can make a difference in the world.
# Growing up as a programmer, despite how powerful computers are, you quickly realize
# how limited they are.
# In particular, they lack
# judgment and intelligence.
# Programming is the art
# of giving clear robotic instructions to computers to accomplish
# simple objectives.
# It’s all black and white,
# and there’s no gray area.
# As I learned about AI,
# it was clearly transformational.
# It changed the game.
# It equipped computers with intelligence,
# and I knew I wanted to be deeply involved.
# I was studying AI at MIT and slowly
# became more and more excited about all the potential applications of AI
# for solving more nuanced problems.
# For example, there was one class project where I worked on applying AI
# to human emotions.
# The goal was to take picture
# of human expressions and ultimately identify and understand
# the emotion through very subtle signals in facial expressions.
# Using AI, we built an algorithm that was able to detect intent
# with 80% accuracy and efficacy.
# We were extremely proud of that.
# It was the start of using AI to do
# entirely new things using computers.
# That’s when I realize
# the implications of AI and how it could tackle the gray areas
# that involve judgment or intelligence.
# You see, AI needs humans
# to teach it individual values, nudge it to find thoughtful outcomes, and ensure that human intentions
# and values are aligned with the AI.
# It was a revelation.
# Before, coding was like
# a black-and-white film versus watching in technicolor.
# What’s more, AI has the potential
# to take away the repetition in our lives, meaning that new and fresh ideas
# will matter more and ultimately enable us to be more human.
# But, to power AI,
# you need powerful data, which was especially hard to come by
# at that time, in 2016, while I was at MIT.
# I realized that nobody was building
# anything with AI outside of school.
# It’s unusual for MIT students
# to not be building something.
# Mechanical engineering majors
# are building catapults in the lawn, electrical engineering majors
# are building robots, and computer science majors are building
# apps for their friends to use.
# But nobody was building
# anything using AI.
# That’s when I discovered what
# a bottleneck data can be to building meaningful
# and powerful AI systems.
# You can't treat data as an afterthought.
# Bad data or lack of data
# results in bad AI.
# I even realize this in my personal life.
# I put a camera inside my fridge
# to gather data, to tell me when to refill my groceries
# and what I needed to buy.
# That’s when I realized
# just how much data I needed to actually be able
# to successfully predict what to purchase.
# There’s no way I could create enough data to be successful
# with the algorithms on my own.
# But it did help me discover
# that my roommate was stealing my food.
# (Laughter)
# At that point, I realized that this was going to be
# a pivotal problem for AI.
# Building large-scale,
# high-quality datasets to power every single application.
# This was the impetus
# behind starting Scale: quality data, to create
# reliable AI outcomes, requires human insight and guidance.
# If you think about the core setup of AI,
# the algorithms need data, and data needs humans.
# To ensure data is accurate, an expert human is often required.
# Only humans can understand
# the context and nuance to properly annotate
# the data to be fed to algorithms.
# Humans are the one who teach
# the algorithms what to do.
# They’re the ones making the decisions,
# they guide them.
# If something happens,
# here’s what you should do.
# And AI learns from that
# and replicates it.
# We are teaching the AI
# our individual values and nudging the AI
# to find thoughtful outcomes.
# Machines make mistakes.
# We have to teach them and
# incentivize them to tell the truth.
# This is why teaching the AI human
# intentions and values is so important.
# It’s through this process
# that we will ensure that AI will have fair, ethical outcomes
# in line with human values.
# It’s this alignment
# that we must solve for.
# The constant alignment of AI to human
# intentions will always require humans.
# and human ideas and creativity
# can actually matter much more, with the power of AI behind them.
# The long tale of real-world problems, and the fact that there’s always
# unknown unknowns means that humans
# will never be fully removed from the AI development lifecycle.
# For example, I remember back in 2016 when chatbots were first starting
# to become a big thing.
# It was right when we were starting Scale.
# We were all thinking there's no way
# to build a fully automated system.
# There’re so many different conversations
# that can have so many different pathways.
# It’s hard to build AI systems that can
# properly handle all these possibilities.
# For chatbots to work, there’re humans
# behind it who make the decisions once, and from there, the chatbots
# can replicate that over and over again.
# That’s again why it’s impossible
# for AI to improve or change without human input.
# Let’s take you to the front lines of AI.
# The things that AI automates first
# are not what you might expect.
# An unintuitive example is the weather.
# Humans have tried for many millennia to crack the code
# of how to predict the weather.
# It’s especially hard for meteorologists because there are
# so many different small things that can cause massive impacts
# on the weather.
# It's the butterfly effect.
# Different elements react to one another
# in unexpected ways.
# There’re so many inputs
# that affect the weather, way more data than any person
# would be able to comprehend on their own.
# That’s why we need AI
# to analyze the vast oceans of data and provide more accurate, nuanced,
# and comprehensive analysis.
# At the moment, AI can already provide extremely accurate
# short-term predictions, including for critical storms and floods.
# So, it’s not what humans perceive
# to be the simplest task that AI will automate first,
# but rather where we have the most data.
# The use cases the brightest minds
# are focusing on are much more positive
# than what you might think.
# Much more so than Terminator or Westworld.
# That’s again why I think AI
# will be a supercharger for humanity.
# Unlike the movies, AI developers
# aren’t focusing their attention on building replacements for humans.
# They’re building tools
# to help free up our time and energy to focus on what human
# can uniquely solve.
# A good example about how AI
# can be used in practice is health care.
# According to the Association
# of American Medical Colleges, the United States could see
# an estimated shortage of between 38,000
# and 124,000 physicians by 2034.
# AI could save doctors’ time
# with rogue tasks and ultimately enable them to serve
# more patients and help more people.
# Health care is full of repetitive tasks
# which are right for AI.
# When a patient is sick,
# they go through all kinds of tests which produce all sorts of data:
# blood tests, imagery, lab results, X-rays, etc.
# Doctors then analyze all this data
# to make decisions about a case.
# AI can analyze all this data proactively and go through a list of possibilities by cross-referencing
# against all prior data in cases.
# It can identify when something isn’t right
# long before a physician can and flag it to a physician,
# if it requires more attention.
# With AI,
# doctors are still integral to the process, but it takes less time to get a diagnosis.
# You have to wait several weeks for your case to go
# from one doctor to another.
# The AI will supercharge,
# finding a diagnosis faster.
# Similarly, in the field of drug discovery,
# it’s all about using complex data: experiment data, patient data, protein simulations and far more to guide a more efficient process of solving diseas
# through new drugs and compounds.
# Recent advancements in AI have dramatically sped up
# the scientific process by allowing us to process and make us
# of more  data than ever before.
# Another good example, and potentially
# more concrete, is the Russia-Ukraine war.
# We've all seen the images of tanks
# lining up ready to enter Kiev.
# AI can help assess satellite imagery
# with superhuman speed and precision, so Ukrainian forces can respond faster.
# At Scale, we’re using our platform
# to do damage assessment in key areas affected by the war.
# We’ve rapidly analyzed
# over 2,000 square kilometers of Ukraine, identifying over 370,000 structures, including thousands not previously
# available via other datasets.
# We focused on Kiev, Kharkiv and Dnipro, in which we provided some data
# directly to government and users.
# We also made the data publicly available
# to the broader AI community via Scale.
# We can also use this data
# to  maximize allocations of resources, people or commodities.
# It’s clear satellite data
# can be extremely useful in these types of situations.
# Thanks to satellite data,
# AI can analyze if planes or tanks have been moved from one place to another.
# This is called change detection.
# Algorithms can constantly be monitoring
# for this kind of data, and if it notices a change or movement, it will alert a human
# to further investigate, otherwise known as predictive modeling.
# AI can also help us understand
# the economic impacts of war.
# We can use AI to track
# farmland in Ukraine and measure the agricultural damage
# in real time.
# Ukraine is a major food supplier
# for much of the world.
# Understanding these impacts
# is absolutely critical.
# In conclusion, AI is not
# something to be feared, but it’s a tool that can be used
# to better understand… that needs to be better understood, and has the potential
# to transform our lives for the better.
# AI enables us to make use and sense
# of massive amounts of data that has historically been
# beyond human capacity.
# It allows us to add
# intelligence and nuance to automated systems
# that will dramatically improve humanity.
# Areas like health care and agriculture.
# This then allows humans
# to do what they do best.
# Take this information,
# put it into context with sensitivity, to strategize and act in a timely manner.
# AI is a supercharger for humanity.
# When AI is better than humans, it makes humans better.
# AI will automate repetitive tasks that don’t require
# constant human judgment or creativity, which frees us up to explore
# and focus on fresher, newer ideas.
# AI will enable us to be
# even more creative and more idea-driven, which I personally find
# incredibly exciting.
# It allows us to embrace
# the generative aspects of human nature, so we can run faster with ideas and build better
# and more powerful solutions to the world’s biggest problems.
# That’s why I believe
# that human-led AI is the path forward, and I’m proud to usher all of us
# into a future with human-led AI.
# Thank you.
# (Applause)

# %% [markdown]
# ### Task 5: Get all Tokens from Document

# %%
tokens = [token.text for token in document]
tokens
# Out:
# [' ',
#  'Transcriber',
#  ':',
#  'Reihaneh',
#  'Iranmanesh',
#  '\n',
#  'Reviewer',
#  ':',
#  'Elisabeth',
#  'Buffard',
#  'When',
#  'most',
#  'people',
#  'think',
#  'about',
#  'AI',
#  ',',
#  'they',
#  'picture',
#  'a',
#  'sci',
#  '-',
#  'fi',
#  'dystopian',
#  'future',
#  ',',
#  '\n',
#  'with',
#  'man',
#  'versus',
#  'machine',
#  '.',
#  'Terminator',
#  ',',
#  'Skynet',
#  ',',
#  'Black',
#  'Mirror',
#  ',',
#  '\n',
#  'Blade',
#  'Runner',
#  ',',
#  'Westworld',
#  '.',
#  'But',
#  'as',
#  'someone',
#  'who',
#  'is',
#  'working',
#  'on',
#  'the',
#  'most',
#  'ambitious',
#  '\n',
#  'AI',
#  'projects',
#  'in',
#  'the',
#  'world',
#  ',',
#  'every',
#  'day',
#  ',',
#  'I',
#  'can',
#  'tell',
#  'you',
#  '\n',
#  'that',
#  'is',
#  'far',
#  'from',
#  'reality',
#  '.',
#  'To',
#  'me',
#  ',',
#  'it',
#  '’s',
#  'the',
#  'contrary',
#  'of',
#  'that',
#  '.',
#  'AI',
#  'enhances',
#  '\n',
#  'and',
#  'even',
#  'supercharges',
#  'humanity',
#  '.',
#  'Let',
#  'me',
#  'explain',
#  'why',
#  '.',
#  'There',
#  'are',
#  'many',
#  'reasons',
#  '\n',
#  'why',
#  'AI',
#  'will',
#  'never',
#  'replace',
#  'humans',
#  '.',
#  'AI',
#  'always',
#  'has',
#  ',',
#  '\n',
#  'and',
#  'always',
#  'will',
#  ',',
#  'rely',
#  'on',
#  'humans',
#  '.',
#  'That',
#  '’s',
#  'one',
#  'of',
#  'the',
#  'reasons',
#  'that',
#  'I',
#  'was',
#  'actually',
#  'inspired',
#  '\n',
#  'to',
#  'start',
#  'an',
#  'AI',
#  'company',
#  '.',
#  'That',
#  'and',
#  'my',
#  'background',
#  '\n',
#  'have',
#  'had',
#  'a',
#  'huge',
#  'impact',
#  'on',
#  'me',
#  'and',
#  'why',
#  'I',
#  'started',
#  'Scale',
#  '.',
#  'My',
#  'parents',
#  'were',
#  'brilliant',
#  'scientists',
#  '\n',
#  'of',
#  'Los',
#  'Alamos',
#  ',',
#  'who',
#  'accomplished',
#  'a',
#  'lot',
#  '\n',
#  'in',
#  'advancing',
#  'their',
#  'field',
#  '.',
#  'That',
#  'inspired',
#  'me',
#  'to',
#  'use',
#  '\n',
#  'science',
#  'and',
#  'technology',
#  'to',
#  'have',
#  'a',
#  'real',
#  'impact',
#  'on',
#  'the',
#  'world',
#  '.',
#  'My',
#  'dad',
#  'was',
#  'a',
#  'physicist',
#  ',',
#  '\n',
#  'and',
#  'my',
#  'mom',
#  'was',
#  'an',
#  'astrophysicist',
#  ',',
#  'both',
#  'at',
#  'the',
#  'top',
#  'of',
#  'their',
#  'field',
#  ',',
#  'who',
#  'made',
#  'meaningful',
#  'contributions',
#  '\n',
#  'to',
#  'plasma',
#  'fluid',
#  'dynamics',
#  'and',
#  'the',
#  'beginnings',
#  'of',
#  'the',
#  'universe',
#  '.',
#  'Their',
#  'scientific',
#  'work',
#  'will',
#  'have',
#  '\n',
#  'meaningful',
#  'impact',
#  'on',
#  'how',
#  'we',
#  'understand',
#  '\n',
#  'and',
#  'perceive',
#  'our',
#  'world',
#  '.',
#  'And',
#  'I',
#  'wanted',
#  'to',
#  'work',
#  '\n',
#  'on',
#  'something',
#  'as',
#  'impactful',
#  'or',
#  'even',
#  'more',
#  'impactful',
#  'than',
#  'that',
#  '.',
#  'That',
#  '’s',
#  'why',
#  'I',
#  'decide',
#  '\n',
#  'to',
#  'become',
#  'a',
#  'programmer',
#  ',',
#  'so',
#  'I',
#  'can',
#  'make',
#  'a',
#  'difference',
#  'in',
#  'the',
#  'world',
#  '.',
#  'Growing',
#  'up',
#  'as',
#  'a',
#  'programmer',
#  ',',
#  'despite',
#  'how',
#  'powerful',
#  'computers',
#  'are',
#  ',',
#  'you',
#  'quickly',
#  'realize',
#  '\n',
#  'how',
#  'limited',
#  'they',
#  'are',
#  '.',
#  'In',
#  'particular',
#  ',',
#  'they',
#  'lack',
#  '\n',
#  'judgment',
#  'and',
#  'intelligence',
#  '.',
#  'Programming',
#  'is',
#  'the',
#  'art',
#  '\n',
#  'of',
#  'giving',
#  'clear',
#  'robotic',
#  'instructions',
#  'to',
#  'computers',
#  'to',
#  'accomplish',
#  '\n',
#  'simple',
#  'objectives',
#  '.',
#  'It',
#  '’s',
#  'all',
#  'black',
#  'and',
#  'white',
#  ',',
#  '\n',
#  'and',
#  'there',
#  '’s',
#  'no',
#  'gray',
#  'area',
#  '.',
#  'As',
#  'I',
#  'learned',
#  'about',
#  'AI',
#  ',',
#  '\n',
#  'it',
#  'was',
#  'clearly',
#  'transformational',
#  '.',
#  'It',
#  'changed',
#  'the',
#  'game',
#  '.',
#  'It',
#  'equipped',
#  'computers',
#  'with',
#  'intelligence',
#  ',',
#  '\n',
#  'and',
#  'I',
#  'knew',
#  'I',
#  'wanted',
#  'to',
#  'be',
#  'deeply',
#  'involved',
#  '.',
#  'I',
#  'was',
#  'studying',
#  'AI',
#  'at',
#  'MIT',
#  'and',
#  'slowly',
#  '\n',
#  'became',
#  'more',
#  'and',
#  'more',
#  'excited',
#  'about',
#  'all',
#  'the',
#  'potential',
#  'applications',
#  'of',
#  'AI',
#  '\n',
#  'for',
#  'solving',
#  'more',
#  'nuanced',
#  'problems',
#  '.',
#  'For',
#  'example',
#  ',',
#  'there',
#  'was',
#  'one',
#  'class',
#  'project',
#  'where',
#  'I',
#  'worked',
#  'on',
#  'applying',
#  'AI',
#  '\n',
#  'to',
#  'human',
#  'emotions',
#  '.',
#  'The',
#  'goal',
#  'was',
#  'to',
#  'take',
#  'picture',
#  '\n',
#  'of',
#  'human',
#  'expressions',
#  'and',
#  'ultimately',
#  'identify',
#  'and',
#  'understand',
#  '\n',
#  'the',
#  'emotion',
#  'through',
#  'very',
#  'subtle',
#  'signals',
#  'in',
#  'facial',
#  'expressions',
#  '.',
#  'Using',
#  'AI',
#  ',',
#  'we',
#  'built',
#  'an',
#  'algorithm',
#  'that',
#  'was',
#  'able',
#  'to',
#  'detect',
#  'intent',
#  '\n',
#  'with',
#  '80',
#  '%',
#  'accuracy',
#  'and',
#  'efficacy',
#  '.',
#  'We',
#  'were',
#  'extremely',
#  'proud',
#  'of',
#  'that',
#  '.',
#  'It',
#  'was',
#  'the',
#  'start',
#  'of',
#  'using',
#  'AI',
#  'to',
#  'do',
#  '\n',
#  'entirely',
#  'new',
#  'things',
#  'using',
#  'computers',
#  '.',
#  'That',
#  '’s',
#  'when',
#  'I',
#  'realize',
#  '\n',
#  'the',
#  'implications',
#  'of',
#  'AI',
#  'and',
#  'how',
#  'it',
#  'could',
#  'tackle',
#  'the',
#  'gray',
#  'areas',
#  '\n',
#  'that',
#  'involve',
#  'judgment',
#  'or',
#  'intelligence',
#  '.',
#  'You',
#  'see',
#  ',',
#  'AI',
#  'needs',
#  'humans',
#  '\n',
#  'to',
#  'teach',
#  'it',
#  'individual',
#  'values',
#  ',',
#  'nudge',
#  'it',
#  'to',
#  'find',
#  'thoughtful',
#  'outcomes',
#  ',',
#  'and',
#  'ensure',
#  'that',
#  'human',
#  'intentions',
#  '\n',
#  'and',
#  'values',
#  'are',
#  'aligned',
#  'with',
#  'the',
#  'AI',
#  '.',
#  'It',
#  'was',
#  'a',
#  'revelation',
#  '.',
#  'Before',
#  ',',
#  'coding',
#  'was',
#  'like',
#  '\n',
#  'a',
#  'black',
#  '-',
#  'and',
#  '-',
#  'white',
#  'film',
#  'versus',
#  'watching',
#  'in',
#  'technicolor',
#  '.',
#  'What',
#  '’s',
#  'more',
#  ',',
#  'AI',
#  'has',
#  'the',
#  'potential',
#  '\n',
#  'to',
#  'take',
#  'away',
#  'the',
#  'repetition',
#  'in',
#  'our',
#  'lives',
#  ',',
#  'meaning',
#  'that',
#  'new',
#  'and',
#  'fresh',
#  'ideas',
#  '\n',
#  'will',
#  'matter',
#  'more',
#  'and',
#  'ultimately',
#  'enable',
#  'us',
#  'to',
#  'be',
#  'more',
#  'human',
#  '.',
#  'But',
#  ',',
#  'to',
#  'power',
#  'AI',
#  ',',
#  '\n',
#  'you',
#  'need',
#  'powerful',
#  'data',
#  ',',
#  'which',
#  'was',
#  'especially',
#  'hard',
#  'to',
#  'come',
#  'by',
#  '\n',
#  'at',
#  'that',
#  'time',
#  ',',
#  'in',
#  '2016',
#  ',',
#  'while',
#  'I',
#  'was',
#  'at',
#  'MIT',
#  '.',
#  'I',
#  'realized',
#  'that',
#  'nobody',
#  'was',
#  'building',
#  '\n',
#  'anything',
#  'with',
#  'AI',
#  'outside',
#  'of',
#  'school',
#  '.',
#  'It',
#  '’s',
#  'unusual',
#  'for',
#  'MIT',
#  'students',
#  '\n',
#  'to',
#  'not',
#  'be',
#  'building',
#  'something',
#  '.',
#  'Mechanical',
#  'engineering',
#  'majors',
#  '\n',
#  'are',
#  'building',
#  'catapults',
#  'in',
#  'the',
#  'lawn',
#  ',',
#  'electrical',
#  'engineering',
#  'majors',
#  '\n',
#  'are',
#  'building',
#  'robots',
#  ',',
#  'and',
#  'computer',
#  'science',
#  'majors',
#  'are',
#  'building',
#  '\n',
#  'apps',
#  'for',
#  'their',
#  'friends',
#  'to',
#  'use',
#  '.',
#  'But',
#  'nobody',
#  'was',
#  'building',
#  '\n',
#  'anything',
#  'using',
#  'AI',
#  '.',
#  'That',
#  '’s',
#  'when',
#  'I',
#  'discovered',
#  'what',
#  '\n',
#  'a',
#  'bottleneck',
#  'data',
#  'can',
#  'be',
#  'to',
#  'building',
#  'meaningful',
#  '\n',
#  'and',
#  'powerful',
#  'AI',
#  'systems',
#  '.',
#  'You',
#  'ca',
#  "n't",
#  'treat',
#  'data',
#  'as',
#  'an',
#  'afterthought',
#  '.',
#  'Bad',
#  'data',
#  'or',
#  'lack',
#  'of',
#  'data',
#  '\n',
#  'results',
#  'in',
#  'bad',
#  'AI',
#  '.',
#  'I',
#  'even',
#  'realize',
#  'this',
#  'in',
#  'my',
#  'personal',
#  'life',
#  '.',
#  'I',
#  'put',
#  'a',
#  'camera',
#  'inside',
#  'my',
#  'fridge',
#  '\n',
#  'to',
#  'gather',
#  'data',
#  ',',
#  'to',
#  'tell',
#  'me',
#  'when',
#  'to',
#  'refill',
#  'my',
#  'groceries',
#  '\n',
#  'and',
#  'what',
#  'I',
#  'needed',
#  'to',
#  'buy',
#  '.',
#  'That',
#  '’s',
#  'when',
#  'I',
#  'realized',
#  '\n',
#  'just',
#  'how',
#  'much',
#  'data',
#  'I',
#  'needed',
#  'to',
#  'actually',
#  'be',
#  'able',
#  '\n',
#  'to',
#  'successfully',
#  'predict',
#  'what',
#  'to',
#  'purchase',
#  '.',
#  'There',
#  '’s',
#  'no',
#  'way',
#  'I',
#  'could',
#  'create',
#  'enough',
#  'data',
#  'to',
#  'be',
#  'successful',
#  '\n',
#  'with',
#  'the',
#  'algorithms',
#  'on',
#  'my',
#  'own',
#  '.',
#  'But',
#  'it',
#  'did',
#  'help',
#  'me',
#  'discover',
#  '\n',
#  'that',
#  'my',
#  'roommate',
#  'was',
#  'stealing',
#  'my',
#  'food',
#  '.',
#  '(',
#  'Laughter',
#  ')',
#  'At',
#  'that',
#  'point',
#  ',',
#  'I',
#  'realized',
#  'that',
#  'this',
#  'was',
#  'going',
#  'to',
#  'be',
#  '\n',
#  'a',
#  'pivotal',
#  'problem',
#  'for',
#  'AI',
#  '.',
#  'Building',
#  'large',
#  '-',
#  'scale',
#  ',',
#  '\n',
#  'high',
#  '-',
#  'quality',
#  'datasets',
#  'to',
#  'power',
#  'every',
#  'single',
#  'application',
#  '.',
#  'This',
#  'was',
#  'the',
#  'impetus',
#  '\n',
#  'behind',
#  'starting',
#  'Scale',
#  ':',
#  'quality',
#  'data',
#  ',',
#  'to',
#  'create',
#  '\n',
#  'reliable',
#  'AI',
#  'outcomes',
#  ',',
#  'requires',
#  'human',
#  'insight',
#  'and',
#  'guidance',
#  '.',
#  'If',
#  'you',
#  'think',
#  'about',
#  'the',
#  'core',
#  'setup',
#  'of',
#  'AI',
#  ',',
#  '\n',
#  'the',
#  'algorithms',
#  'need',
#  'data',
#  ',',
#  'and',
#  'data',
#  'needs',
#  'humans',
#  '.',
#  'To',
#  'ensure',
#  'data',
#  'is',
#  'accurate',
#  ',',
#  'an',
#  'expert',
#  'human',
#  'is',
#  'often',
#  'required',
#  '.',
#  'Only',
#  'humans',
#  'can',
#  'understand',
#  '\n',
#  'the',
#  'context',
#  'and',
#  'nuance',
#  'to',
#  'properly',
#  'annotate',
#  '\n',
#  'the',
#  'data',
#  'to',
#  'be',
#  'fed',
#  'to',
#  'algorithms',
#  '.',
#  'Humans',
#  'are',
#  'the',
#  'one',
#  'who',
#  'teach',
#  '\n',
#  'the',
#  'algorithms',
#  'what',
#  'to',
#  'do',
#  '.',
#  'They',
#  '’re',
#  'the',
#  ...]

# %% [markdown]
# ### Task 6: Calculate Frequency of Tokens

# %%
word_frequencies = {}
for word in document:
    text = word.text.lower()
    if text not in list(STOP_WORDS) and text not in punctuation:
        if word.text not in word_frequencies.keys():
            word_frequencies[word.text] = 1
        else:
            word_frequencies[word.text] += 1
word_frequencies
# Out:
# {' ': 3,
#  'Transcriber': 1,
#  'Reihaneh': 1,
#  'Iranmanesh': 1,
#  '\n': 159,
#  'Reviewer': 1,
#  'Elisabeth': 1,
#  'Buffard': 1,
#  'people': 3,
#  'think': 4,
#  'AI': 61,
#  'picture': 2,
#  'sci': 1,
#  'fi': 1,
#  'dystopian': 1,
#  'future': 2,
#  'man': 1,
#  'versus': 2,
#  'machine': 1,
#  'Terminator': 2,
#  'Skynet': 1,
#  'Black': 1,
#  'Mirror': 1,
#  'Blade': 1,
#  'Runner': 1,
#  'Westworld': 2,
#  'working': 1,
#  'ambitious': 1,
#  'projects': 1,
#  'world': 7,
#  'day': 1,
#  'tell': 3,
#  'far': 2,
#  'reality': 1,
#  'contrary': 1,
#  'enhances': 1,
#  'supercharges': 1,
#  'humanity': 4,
#  'Let': 2,
#  'explain': 1,
#  'reasons': 2,
#  'replace': 1,
#  'humans': 13,
#  'rely': 1,
#  'actually': 3,
#  'inspired': 2,
#  'start': 2,
#  'company': 1,
#  'background': 1,
#  'huge': 1,
#  'impact': 3,
#  'started': 1,
#  'Scale': 5,
#  'parents': 1,
#  'brilliant': 1,
#  'scientists': 1,
#  'Los': 1,
#  'Alamos': 1,
#  'accomplished': 1,
#  'lot': 1,
#  'advancing': 1,
#  'field': 3,
#  'use': 6,
#  'science': 2,
#  'technology': 1,
#  'real': 3,
#  'dad': 1,
#  'physicist': 1,
#  'mom': 1,
#  'astrophysicist': 1,
#  'meaningful': 3,
#  'contributions': 1,
#  'plasma': 1,
#  'fluid': 1,
#  'dynamics': 1,
#  'beginnings': 1,
#  'universe': 1,
#  'scientific': 2,
#  'work': 3,
#  'understand': 5,
#  'perceive': 2,
#  'wanted': 2,
#  'impactful': 2,
#  'decide': 1,
#  'programmer': 2,
#  'difference': 1,
#  'Growing': 1,
#  'despite': 1,
#  'powerful': 4,
#  'computers': 4,
#  'quickly': 1,
#  'realize': 3,
#  'limited': 1,
#  'particular': 1,
#  'lack': 2,
#  'judgment': 3,
#  'intelligence': 4,
#  'Programming': 1,
#  'art': 1,
#  'giving': 1,
#  'clear': 2,
#  'robotic': 1,
#  'instructions': 1,
#  'accomplish': 1,
#  'simple': 1,
#  'objectives': 1,
#  'black': 2,
#  'white': 2,
#  'gray': 2,
#  'area': 1,
#  'learned': 1,
#  'clearly': 1,
#  'transformational': 1,
#  'changed': 1,
#  'game': 1,
#  'equipped': 1,
#  'knew': 1,
#  'deeply': 1,
#  'involved': 1,
#  'studying': 1,
#  'MIT': 3,
#  'slowly': 1,
#  'excited': 1,
#  'potential': 3,
#  'applications': 1,
#  'solving': 2,
#  'nuanced': 2,
#  'problems': 3,
#  'example': 5,
#  'class': 1,
#  'project': 1,
#  'worked': 1,
#  'applying': 1,
#  'human': 18,
#  'emotions': 1,
#  'goal': 1,
#  'expressions': 2,
#  'ultimately': 3,
#  'identify': 2,
#  'emotion': 1,
#  'subtle': 1,
#  'signals': 1,
#  'facial': 1,
#  'built': 1,
#  'algorithm': 1,
#  'able': 3,
#  'detect': 1,
#  'intent': 1,
#  '80': 1,
#  'accuracy': 1,
#  'efficacy': 1,
#  'extremely': 3,
#  'proud': 2,
#  'entirely': 1,
#  'new': 3,
#  'things': 3,
#  'implications': 1,
#  'tackle': 1,
#  'areas': 2,
#  'involve': 1,
#  'needs': 3,
#  'teach': 3,
#  'individual': 2,
#  'values': 5,
#  'nudge': 1,
#  'find': 3,
#  'thoughtful': 2,
#  'outcomes': 4,
#  'ensure': 3,
#  'intentions': 3,
#  'aligned': 1,
#  'revelation': 1,
#  'coding': 1,
#  'like': 2,
#  'film': 1,
#  'watching': 1,
#  'technicolor': 1,
#  'away': 1,
#  'repetition': 1,
#  'lives': 2,
#  'meaning': 1,
#  'fresh': 1,
#  'ideas': 4,
#  'matter': 2,
#  'enable': 3,
#  'power': 3,
#  'need': 3,
#  'data': 31,
#  'especially': 2,
#  'hard': 3,
#  'come': 1,
#  'time': 5,
#  '2016': 2,
#  'realized': 3,
#  'building': 9,
#  'outside': 1,
#  'school': 1,
#  'unusual': 1,
#  'students': 1,
#  'Mechanical': 1,
#  'engineering': 2,
#  'majors': 3,
#  'catapults': 1,
#  'lawn': 1,
#  'electrical': 1,
#  'robots': 1,
#  'computer': 1,
#  'apps': 1,
#  'friends': 1,
#  'discovered': 1,
#  'bottleneck': 1,
#  'systems': 3,
#  'treat': 1,
#  'afterthought': 1,
#  'Bad': 1,
#  'results': 2,
#  'bad': 1,
#  'personal': 1,
#  'life': 1,
#  'camera': 1,
#  'inside': 1,
#  'fridge': 1,
#  'gather': 1,
#  'refill': 1,
#  'groceries': 1,
#  'needed': 2,
#  'buy': 1,
#  'successfully': 1,
#  'predict': 2,
#  'purchase': 1,
#  'way': 3,
#  'create': 2,
#  'successful': 1,
#  'algorithms': 4,
#  'help': 5,
#  'discover': 1,
#  'roommate': 1,
#  'stealing': 1,
#  'food': 2,
#  'Laughter': 1,
#  'point': 1,
#  'going': 1,
#  'pivotal': 1,
#  'problem': 1,
#  'Building': 1,
#  'large': 1,
#  'scale': 1,
#  'high': 1,
#  'quality': 2,
#  'datasets': 2,
#  'single': 1,
#  'application': 1,
#  'impetus': 1,
#  'starting': 3,
#  'reliable': 1,
#  'requires': 2,
#  'insight': 1,
#  'guidance': 1,
#  'core': 1,
#  'setup': 1,
#  'accurate': 3,
#  'expert': 1,
#  'required': 1,
#  'context': 2,
#  'nuance': 2,
#  'properly': 2,
#  'annotate': 1,
#  'fed': 1,
#  'Humans': 2,
#  'ones': 1,
#  'making': 1,
#  'decisions': 3,
#  'guide': 2,
#  'happens': 1,
#  'learns': 1,
#  'replicates': 1,
#  'teaching': 2,
#  'nudging': 1,
#  'Machines': 1,
#  'mistakes': 1,
#  'incentivize': 1,
#  'truth': 1,
#  'important': 1,
#  'process': 5,
#  'fair': 1,
#  'ethical': 1,
#  'line': 1,
#  'alignment': 2,
#  'solve': 2,
#  'constant': 2,
#  'require': 2,
#  'creativity': 2,
#  'long': 2,
#  'tale': 1,
#  'fact': 1,
#  'unknown': 1,
#  'unknowns': 1,
#  'means': 1,
#  'fully': 2,
#  'removed': 1,
#  'development': 1,
#  'lifecycle': 1,
#  'remember': 1,
#  'chatbots': 3,
#  'big': 1,
#  'thing': 1,
#  'right': 3,
#  'thinking': 1,
#  'build': 3,
#  'automated': 2,
#  'system': 1,
#  'different': 3,
#  'conversations': 1,
#  'pathways': 1,
#  'handle': 1,
#  'possibilities': 2,
#  'replicate': 1,
#  'impossible': 1,
#  'improve': 2,
#  'change': 3,
#  'input': 1,
#  'lines': 1,
#  'automates': 1,
#  'expect': 1,
#  'unintuitive': 1,
#  'weather': 4,
#  'tried': 1,
#  'millennia': 1,
#  'crack': 1,
#  'code': 1,
#  'meteorologists': 1,
#  'small': 1,
#  'cause': 1,
#  'massive': 2,
#  'impacts': 3,
#  'butterfly': 1,
#  'effect': 1,
#  'Different': 1,
#  'elements': 1,
#  'react': 1,
#  'unexpected': 1,
#  'ways': 1,
#  'inputs': 1,
#  'affect': 1,
#  'person': 1,
#  'comprehend': 1,
#  'analyze': 4,
#  'vast': 1,
#  'oceans': 1,
#  'provide': 2,
#  'comprehensive': 1,
#  'analysis': 1,
#  'moment': 1,
#  'short': 1,
#  'term': 1,
#  'predictions': 1,
#  'including': 2,
#  'critical': 2,
#  'storms': 1,
#  'floods': 1,
#  'simplest': 1,
#  'task': 1,
#  'automate': 2,
#  'cases': 2,
#  'brightest': 1,
#  'minds': 1,
#  'focusing': 2,
#  'positive': 1,
#  'supercharger': 2,
#  'Unlike': 1,
#  'movies': 1,
#  'developers': 1,
#  'attention': 2,
#  'replacements': 1,
#  'tools': 1,
#  'free': 1,
#  'energy': 1,
#  'focus': 2,
#  'uniquely': 1,
#  'good': 2,
#  'practice': 1,
#  'health': 2,
#  'care': 3,
#  'According': 1,
#  'Association': 1,
#  'American': 1,
#  'Medical': 1,
#  'Colleges': 1,
#  'United': 1,
#  'States': 1,
#  'estimated': 1,
#  'shortage': 1,
#  '38,000': 1,
#  '124,000': 1,
#  'physicians': 1,
#  '2034': 1,
#  'save': 1,
#  'doctors': 2,
#  '’': 1,
#  'rogue': 1,
#  'tasks': 3,
#  'serve': 1,
#  'patients': 1,
#  'Health': 1,
#  'repetitive': 2,
#  'patient': 2,
#  'sick': 1,
#  'kinds': 1,
#  'tests': 2,
#  'produce': 1,
#  'sorts': 1,
#  'blood': 1,
#  'imagery': 2,
#  'lab': 1,
#  'X': 1,
#  'rays': 1,
#  'etc': 1,
#  'Doctors': 1,
#  'case': 2,
#  'proactively': 1,
#  'list': 1,
#  'cross': 1,
#  'referencing': 1,
#  'prior': 1,
#  'physician': 2,
#  'flag': 1,
#  'integral': 1,
#  'takes': 1,
#  'diagnosis': 2,
#  'wait': 1,
#  'weeks': 1,
#  'doctor': 1,
#  'supercharge': 1,
#  'finding': 1,
#  'faster': 3,
#  'Similarly': 1,
#  'drug': 1,
#  'discovery': 1,
#  'complex': 1,
#  'experiment': 1,
#  'protein': 1,
#  'simulations': 1,
#  'efficient': 1,
#  'diseas': 1,
#  'drugs': 1,
#  'compounds': 1,
#  'Recent': 1,
#  'advancements': 1,
#  'dramatically': 2,
#  'sped': 1,
#  'allowing': 1,
#  'potentially': 1,
#  'concrete': 1,
#  'Russia': 1,
#  'Ukraine': 4,
#  'war': 3,
#  'seen': 1,
#  'images': 1,
#  'tanks': 2,
#  'lining': 1,
#  'ready': 1,
#  'enter': 1,
#  'Kiev': 2,
#  'assess': 1,
#  'satellite': 3,
#  'superhuman': 1,
#  'speed': 1,
#  'precision': 1,
#  'Ukrainian': 1,
#  'forces': 1,
#  'respond': 1,
#  'platform': 1,
#  'damage': 2,
#  'assessment': 1,
#  'key': 1,
#  'affected': 1,
#  'rapidly': 1,
#  'analyzed': 1,
#  '2,000': 1,
#  'square': 1,
#  'kilometers': 1,
#  'identifying': 1,
#  '370,000': 1,
#  'structures': 1,
#  'thousands': 1,
#  'previously': 1,
#  'available': 2,
#  'focused': 1,
#  'Kharkiv': 1,
#  'Dnipro': 1,
#  'provided': 1,
#  'directly': 1,
#  'government': 1,
#  'users': 1,
#  'publicly': 1,
#  'broader': 1,
#  'community': 1,
#  'maximize': 1,
#  'allocations': 1,
#  'resources': 1,
#  'commodities': 1,
#  'useful': 1,
#  'types': 1,
#  'situations': 1,
#  'Thanks': 1,
#  'planes': 1,
#  'moved': 1,
#  'place': 1,
#  'called': 1,
#  'detection': 1,
#  'Algorithms': 1,
#  'constantly': 1,
#  'monitoring': 1,
#  'kind': 1,
#  'notices': 1,
#  'movement': 1,
#  'alert': 1,
#  'investigate': 1,
#  'known': 1,
#  'predictive': 1,
#  'modeling': 1,
#  'economic': 1,
#  'track': 1,
#  'farmland': 1,
#  'measure': 1,
#  'agricultural': 1,
#  'major': 1,
#  'supplier': 1,
#  'Understanding': 1,
#  'absolutely': 1,
#  'conclusion': 1,
#  'feared': 1,
#  'tool': 1,
#  'better': 6,
#  '…': 1,
#  'understood': 1,
#  'transform': 1,
#  'enables': 1,
#  'sense': 1,
#  'amounts': 1,
#  'historically': 1,
#  'capacity': 1,
#  'allows': 3,
#  'add': 1,
#  'Areas': 1,
#  'agriculture': 1,
#  'best': 1,
#  'information': 1,
#  'sensitivity': 1,
#  'strategize': 1,
#  'act': 1,
#  'timely': 1,
#  'manner': 1,
#  'makes': 1,
#  'frees': 1,
#  'explore': 1,
#  'fresher': 1,
#  'newer': 1,
#  'creative': 1,
#  'idea': 1,
#  'driven': 1,
#  'personally': 1,
#  'incredibly': 1,
#  'exciting': 1,
#  'embrace': 1,
#  'generative': 1,
#  'aspects': 1,
#  'nature': 1,
#  'run': 1,
#  'solutions': 1,
#  'biggest': 1,
#  'believe': 1,
#  'led': 2,
#  'path': 1,
#  'forward': 1,
#  'usher': 1,
#  'Thank': 1,
#  'Applause': 1}

# %% [markdown]
# ### Task 7: Normalize the Frequency of Tokens

# %%
max_frequency = max(word_frequencies.values())
for word in word_frequencies.keys():
    word_frequencies[word] = word_frequencies[word]/max_frequency
word_frequencies
# Out:
# {' ': 0.018867924528301886,
#  'Transcriber': 0.006289308176100629,
#  'Reihaneh': 0.006289308176100629,
#  'Iranmanesh': 0.006289308176100629,
#  '\n': 1.0,
#  'Reviewer': 0.006289308176100629,
#  'Elisabeth': 0.006289308176100629,
#  'Buffard': 0.006289308176100629,
#  'people': 0.018867924528301886,
#  'think': 0.025157232704402517,
#  'AI': 0.3836477987421384,
#  'picture': 0.012578616352201259,
#  'sci': 0.006289308176100629,
#  'fi': 0.006289308176100629,
#  'dystopian': 0.006289308176100629,
#  'future': 0.012578616352201259,
#  'man': 0.006289308176100629,
#  'versus': 0.012578616352201259,
#  'machine': 0.006289308176100629,
#  'Terminator': 0.012578616352201259,
#  'Skynet': 0.006289308176100629,
#  'Black': 0.006289308176100629,
#  'Mirror': 0.006289308176100629,
#  'Blade': 0.006289308176100629,
#  'Runner': 0.006289308176100629,
#  'Westworld': 0.012578616352201259,
#  'working': 0.006289308176100629,
#  'ambitious': 0.006289308176100629,
#  'projects': 0.006289308176100629,
#  'world': 0.0440251572327044,
#  'day': 0.006289308176100629,
#  'tell': 0.018867924528301886,
#  'far': 0.012578616352201259,
#  'reality': 0.006289308176100629,
#  'contrary': 0.006289308176100629,
#  'enhances': 0.006289308176100629,
#  'supercharges': 0.006289308176100629,
#  'humanity': 0.025157232704402517,
#  'Let': 0.012578616352201259,
#  'explain': 0.006289308176100629,
#  'reasons': 0.012578616352201259,
#  'replace': 0.006289308176100629,
#  'humans': 0.08176100628930817,
#  'rely': 0.006289308176100629,
#  'actually': 0.018867924528301886,
#  'inspired': 0.012578616352201259,
#  'start': 0.012578616352201259,
#  'company': 0.006289308176100629,
#  'background': 0.006289308176100629,
#  'huge': 0.006289308176100629,
#  'impact': 0.018867924528301886,
#  'started': 0.006289308176100629,
#  'Scale': 0.031446540880503145,
#  'parents': 0.006289308176100629,
#  'brilliant': 0.006289308176100629,
#  'scientists': 0.006289308176100629,
#  'Los': 0.006289308176100629,
#  'Alamos': 0.006289308176100629,
#  'accomplished': 0.006289308176100629,
#  'lot': 0.006289308176100629,
#  'advancing': 0.006289308176100629,
#  'field': 0.018867924528301886,
#  'use': 0.03773584905660377,
#  'science': 0.012578616352201259,
#  'technology': 0.006289308176100629,
#  'real': 0.018867924528301886,
#  'dad': 0.006289308176100629,
#  'physicist': 0.006289308176100629,
#  'mom': 0.006289308176100629,
#  'astrophysicist': 0.006289308176100629,
#  'meaningful': 0.018867924528301886,
#  'contributions': 0.006289308176100629,
#  'plasma': 0.006289308176100629,
#  'fluid': 0.006289308176100629,
#  'dynamics': 0.006289308176100629,
#  'beginnings': 0.006289308176100629,
#  'universe': 0.006289308176100629,
#  'scientific': 0.012578616352201259,
#  'work': 0.018867924528301886,
#  'understand': 0.031446540880503145,
#  'perceive': 0.012578616352201259,
#  'wanted': 0.012578616352201259,
#  'impactful': 0.012578616352201259,
#  'decide': 0.006289308176100629,
#  'programmer': 0.012578616352201259,
#  'difference': 0.006289308176100629,
#  'Growing': 0.006289308176100629,
#  'despite': 0.006289308176100629,
#  'powerful': 0.025157232704402517,
#  'computers': 0.025157232704402517,
#  'quickly': 0.006289308176100629,
#  'realize': 0.018867924528301886,
#  'limited': 0.006289308176100629,
#  'particular': 0.006289308176100629,
#  'lack': 0.012578616352201259,
#  'judgment': 0.018867924528301886,
#  'intelligence': 0.025157232704402517,
#  'Programming': 0.006289308176100629,
#  'art': 0.006289308176100629,
#  'giving': 0.006289308176100629,
#  'clear': 0.012578616352201259,
#  'robotic': 0.006289308176100629,
#  'instructions': 0.006289308176100629,
#  'accomplish': 0.006289308176100629,
#  'simple': 0.006289308176100629,
#  'objectives': 0.006289308176100629,
#  'black': 0.012578616352201259,
#  'white': 0.012578616352201259,
#  'gray': 0.012578616352201259,
#  'area': 0.006289308176100629,
#  'learned': 0.006289308176100629,
#  'clearly': 0.006289308176100629,
#  'transformational': 0.006289308176100629,
#  'changed': 0.006289308176100629,
#  'game': 0.006289308176100629,
#  'equipped': 0.006289308176100629,
#  'knew': 0.006289308176100629,
#  'deeply': 0.006289308176100629,
#  'involved': 0.006289308176100629,
#  'studying': 0.006289308176100629,
#  'MIT': 0.018867924528301886,
#  'slowly': 0.006289308176100629,
#  'excited': 0.006289308176100629,
#  'potential': 0.018867924528301886,
#  'applications': 0.006289308176100629,
#  'solving': 0.012578616352201259,
#  'nuanced': 0.012578616352201259,
#  'problems': 0.018867924528301886,
#  'example': 0.031446540880503145,
#  'class': 0.006289308176100629,
#  'project': 0.006289308176100629,
#  'worked': 0.006289308176100629,
#  'applying': 0.006289308176100629,
#  'human': 0.11320754716981132,
#  'emotions': 0.006289308176100629,
#  'goal': 0.006289308176100629,
#  'expressions': 0.012578616352201259,
#  'ultimately': 0.018867924528301886,
#  'identify': 0.012578616352201259,
#  'emotion': 0.006289308176100629,
#  'subtle': 0.006289308176100629,
#  'signals': 0.006289308176100629,
#  'facial': 0.006289308176100629,
#  'built': 0.006289308176100629,
#  'algorithm': 0.006289308176100629,
#  'able': 0.018867924528301886,
#  'detect': 0.006289308176100629,
#  'intent': 0.006289308176100629,
#  '80': 0.006289308176100629,
#  'accuracy': 0.006289308176100629,
#  'efficacy': 0.006289308176100629,
#  'extremely': 0.018867924528301886,
#  'proud': 0.012578616352201259,
#  'entirely': 0.006289308176100629,
#  'new': 0.018867924528301886,
#  'things': 0.018867924528301886,
#  'implications': 0.006289308176100629,
#  'tackle': 0.006289308176100629,
#  'areas': 0.012578616352201259,
#  'involve': 0.006289308176100629,
#  'needs': 0.018867924528301886,
#  'teach': 0.018867924528301886,
#  'individual': 0.012578616352201259,
#  'values': 0.031446540880503145,
#  'nudge': 0.006289308176100629,
#  'find': 0.018867924528301886,
#  'thoughtful': 0.012578616352201259,
#  'outcomes': 0.025157232704402517,
#  'ensure': 0.018867924528301886,
#  'intentions': 0.018867924528301886,
#  'aligned': 0.006289308176100629,
#  'revelation': 0.006289308176100629,
#  'coding': 0.006289308176100629,
#  'like': 0.012578616352201259,
#  'film': 0.006289308176100629,
#  'watching': 0.006289308176100629,
#  'technicolor': 0.006289308176100629,
#  'away': 0.006289308176100629,
#  'repetition': 0.006289308176100629,
#  'lives': 0.012578616352201259,
#  'meaning': 0.006289308176100629,
#  'fresh': 0.006289308176100629,
#  'ideas': 0.025157232704402517,
#  'matter': 0.012578616352201259,
#  'enable': 0.018867924528301886,
#  'power': 0.018867924528301886,
#  'need': 0.018867924528301886,
#  'data': 0.1949685534591195,
#  'especially': 0.012578616352201259,
#  'hard': 0.018867924528301886,
#  'come': 0.006289308176100629,
#  'time': 0.031446540880503145,
#  '2016': 0.012578616352201259,
#  'realized': 0.018867924528301886,
#  'building': 0.05660377358490566,
#  'outside': 0.006289308176100629,
#  'school': 0.006289308176100629,
#  'unusual': 0.006289308176100629,
#  'students': 0.006289308176100629,
#  'Mechanical': 0.006289308176100629,
#  'engineering': 0.012578616352201259,
#  'majors': 0.018867924528301886,
#  'catapults': 0.006289308176100629,
#  'lawn': 0.006289308176100629,
#  'electrical': 0.006289308176100629,
#  'robots': 0.006289308176100629,
#  'computer': 0.006289308176100629,
#  'apps': 0.006289308176100629,
#  'friends': 0.006289308176100629,
#  'discovered': 0.006289308176100629,
#  'bottleneck': 0.006289308176100629,
#  'systems': 0.018867924528301886,
#  'treat': 0.006289308176100629,
#  'afterthought': 0.006289308176100629,
#  'Bad': 0.006289308176100629,
#  'results': 0.012578616352201259,
#  'bad': 0.006289308176100629,
#  'personal': 0.006289308176100629,
#  'life': 0.006289308176100629,
#  'camera': 0.006289308176100629,
#  'inside': 0.006289308176100629,
#  'fridge': 0.006289308176100629,
#  'gather': 0.006289308176100629,
#  'refill': 0.006289308176100629,
#  'groceries': 0.006289308176100629,
#  'needed': 0.012578616352201259,
#  'buy': 0.006289308176100629,
#  'successfully': 0.006289308176100629,
#  'predict': 0.012578616352201259,
#  'purchase': 0.006289308176100629,
#  'way': 0.018867924528301886,
#  'create': 0.012578616352201259,
#  'successful': 0.006289308176100629,
#  'algorithms': 0.025157232704402517,
#  'help': 0.031446540880503145,
#  'discover': 0.006289308176100629,
#  'roommate': 0.006289308176100629,
#  'stealing': 0.006289308176100629,
#  'food': 0.012578616352201259,
#  'Laughter': 0.006289308176100629,
#  'point': 0.006289308176100629,
#  'going': 0.006289308176100629,
#  'pivotal': 0.006289308176100629,
#  'problem': 0.006289308176100629,
#  'Building': 0.006289308176100629,
#  'large': 0.006289308176100629,
#  'scale': 0.006289308176100629,
#  'high': 0.006289308176100629,
#  'quality': 0.012578616352201259,
#  'datasets': 0.012578616352201259,
#  'single': 0.006289308176100629,
#  'application': 0.006289308176100629,
#  'impetus': 0.006289308176100629,
#  'starting': 0.018867924528301886,
#  'reliable': 0.006289308176100629,
#  'requires': 0.012578616352201259,
#  'insight': 0.006289308176100629,
#  'guidance': 0.006289308176100629,
#  'core': 0.006289308176100629,
#  'setup': 0.006289308176100629,
#  'accurate': 0.018867924528301886,
#  'expert': 0.006289308176100629,
#  'required': 0.006289308176100629,
#  'context': 0.012578616352201259,
#  'nuance': 0.012578616352201259,
#  'properly': 0.012578616352201259,
#  'annotate': 0.006289308176100629,
#  'fed': 0.006289308176100629,
#  'Humans': 0.012578616352201259,
#  'ones': 0.006289308176100629,
#  'making': 0.006289308176100629,
#  'decisions': 0.018867924528301886,
#  'guide': 0.012578616352201259,
#  'happens': 0.006289308176100629,
#  'learns': 0.006289308176100629,
#  'replicates': 0.006289308176100629,
#  'teaching': 0.012578616352201259,
#  'nudging': 0.006289308176100629,
#  'Machines': 0.006289308176100629,
#  'mistakes': 0.006289308176100629,
#  'incentivize': 0.006289308176100629,
#  'truth': 0.006289308176100629,
#  'important': 0.006289308176100629,
#  'process': 0.031446540880503145,
#  'fair': 0.006289308176100629,
#  'ethical': 0.006289308176100629,
#  'line': 0.006289308176100629,
#  'alignment': 0.012578616352201259,
#  'solve': 0.012578616352201259,
#  'constant': 0.012578616352201259,
#  'require': 0.012578616352201259,
#  'creativity': 0.012578616352201259,
#  'long': 0.012578616352201259,
#  'tale': 0.006289308176100629,
#  'fact': 0.006289308176100629,
#  'unknown': 0.006289308176100629,
#  'unknowns': 0.006289308176100629,
#  'means': 0.006289308176100629,
#  'fully': 0.012578616352201259,
#  'removed': 0.006289308176100629,
#  'development': 0.006289308176100629,
#  'lifecycle': 0.006289308176100629,
#  'remember': 0.006289308176100629,
#  'chatbots': 0.018867924528301886,
#  'big': 0.006289308176100629,
#  'thing': 0.006289308176100629,
#  'right': 0.018867924528301886,
#  'thinking': 0.006289308176100629,
#  'build': 0.018867924528301886,
#  'automated': 0.012578616352201259,
#  'system': 0.006289308176100629,
#  'different': 0.018867924528301886,
#  'conversations': 0.006289308176100629,
#  'pathways': 0.006289308176100629,
#  'handle': 0.006289308176100629,
#  'possibilities': 0.012578616352201259,
#  'replicate': 0.006289308176100629,
#  'impossible': 0.006289308176100629,
#  'improve': 0.012578616352201259,
#  'change': 0.018867924528301886,
#  'input': 0.006289308176100629,
#  'lines': 0.006289308176100629,
#  'automates': 0.006289308176100629,
#  'expect': 0.006289308176100629,
#  'unintuitive': 0.006289308176100629,
#  'weather': 0.025157232704402517,
#  'tried': 0.006289308176100629,
#  'millennia': 0.006289308176100629,
#  'crack': 0.006289308176100629,
#  'code': 0.006289308176100629,
#  'meteorologists': 0.006289308176100629,
#  'small': 0.006289308176100629,
#  'cause': 0.006289308176100629,
#  'massive': 0.012578616352201259,
#  'impacts': 0.018867924528301886,
#  'butterfly': 0.006289308176100629,
#  'effect': 0.006289308176100629,
#  'Different': 0.006289308176100629,
#  'elements': 0.006289308176100629,
#  'react': 0.006289308176100629,
#  'unexpected': 0.006289308176100629,
#  'ways': 0.006289308176100629,
#  'inputs': 0.006289308176100629,
#  'affect': 0.006289308176100629,
#  'person': 0.006289308176100629,
#  'comprehend': 0.006289308176100629,
#  'analyze': 0.025157232704402517,
#  'vast': 0.006289308176100629,
#  'oceans': 0.006289308176100629,
#  'provide': 0.012578616352201259,
#  'comprehensive': 0.006289308176100629,
#  'analysis': 0.006289308176100629,
#  'moment': 0.006289308176100629,
#  'short': 0.006289308176100629,
#  'term': 0.006289308176100629,
#  'predictions': 0.006289308176100629,
#  'including': 0.012578616352201259,
#  'critical': 0.012578616352201259,
#  'storms': 0.006289308176100629,
#  'floods': 0.006289308176100629,
#  'simplest': 0.006289308176100629,
#  'task': 0.006289308176100629,
#  'automate': 0.012578616352201259,
#  'cases': 0.012578616352201259,
#  'brightest': 0.006289308176100629,
#  'minds': 0.006289308176100629,
#  'focusing': 0.012578616352201259,
#  'positive': 0.006289308176100629,
#  'supercharger': 0.012578616352201259,
#  'Unlike': 0.006289308176100629,
#  'movies': 0.006289308176100629,
#  'developers': 0.006289308176100629,
#  'attention': 0.012578616352201259,
#  'replacements': 0.006289308176100629,
#  'tools': 0.006289308176100629,
#  'free': 0.006289308176100629,
#  'energy': 0.006289308176100629,
#  'focus': 0.012578616352201259,
#  'uniquely': 0.006289308176100629,
#  'good': 0.012578616352201259,
#  'practice': 0.006289308176100629,
#  'health': 0.012578616352201259,
#  'care': 0.018867924528301886,
#  'According': 0.006289308176100629,
#  'Association': 0.006289308176100629,
#  'American': 0.006289308176100629,
#  'Medical': 0.006289308176100629,
#  'Colleges': 0.006289308176100629,
#  'United': 0.006289308176100629,
#  'States': 0.006289308176100629,
#  'estimated': 0.006289308176100629,
#  'shortage': 0.006289308176100629,
#  '38,000': 0.006289308176100629,
#  '124,000': 0.006289308176100629,
#  'physicians': 0.006289308176100629,
#  '2034': 0.006289308176100629,
#  'save': 0.006289308176100629,
#  'doctors': 0.012578616352201259,
#  '’': 0.006289308176100629,
#  'rogue': 0.006289308176100629,
#  'tasks': 0.018867924528301886,
#  'serve': 0.006289308176100629,
#  'patients': 0.006289308176100629,
#  'Health': 0.006289308176100629,
#  'repetitive': 0.012578616352201259,
#  'patient': 0.012578616352201259,
#  'sick': 0.006289308176100629,
#  'kinds': 0.006289308176100629,
#  'tests': 0.012578616352201259,
#  'produce': 0.006289308176100629,
#  'sorts': 0.006289308176100629,
#  'blood': 0.006289308176100629,
#  'imagery': 0.012578616352201259,
#  'lab': 0.006289308176100629,
#  'X': 0.006289308176100629,
#  'rays': 0.006289308176100629,
#  'etc': 0.006289308176100629,
#  'Doctors': 0.006289308176100629,
#  'case': 0.012578616352201259,
#  'proactively': 0.006289308176100629,
#  'list': 0.006289308176100629,
#  'cross': 0.006289308176100629,
#  'referencing': 0.006289308176100629,
#  'prior': 0.006289308176100629,
#  'physician': 0.012578616352201259,
#  'flag': 0.006289308176100629,
#  'integral': 0.006289308176100629,
#  'takes': 0.006289308176100629,
#  'diagnosis': 0.012578616352201259,
#  'wait': 0.006289308176100629,
#  'weeks': 0.006289308176100629,
#  'doctor': 0.006289308176100629,
#  'supercharge': 0.006289308176100629,
#  'finding': 0.006289308176100629,
#  'faster': 0.018867924528301886,
#  'Similarly': 0.006289308176100629,
#  'drug': 0.006289308176100629,
#  'discovery': 0.006289308176100629,
#  'complex': 0.006289308176100629,
#  'experiment': 0.006289308176100629,
#  'protein': 0.006289308176100629,
#  'simulations': 0.006289308176100629,
#  'efficient': 0.006289308176100629,
#  'diseas': 0.006289308176100629,
#  'drugs': 0.006289308176100629,
#  'compounds': 0.006289308176100629,
#  'Recent': 0.006289308176100629,
#  'advancements': 0.006289308176100629,
#  'dramatically': 0.012578616352201259,
#  'sped': 0.006289308176100629,
#  'allowing': 0.006289308176100629,
#  'potentially': 0.006289308176100629,
#  'concrete': 0.006289308176100629,
#  'Russia': 0.006289308176100629,
#  'Ukraine': 0.025157232704402517,
#  'war': 0.018867924528301886,
#  'seen': 0.006289308176100629,
#  'images': 0.006289308176100629,
#  'tanks': 0.012578616352201259,
#  'lining': 0.006289308176100629,
#  'ready': 0.006289308176100629,
#  'enter': 0.006289308176100629,
#  'Kiev': 0.012578616352201259,
#  'assess': 0.006289308176100629,
#  'satellite': 0.018867924528301886,
#  'superhuman': 0.006289308176100629,
#  'speed': 0.006289308176100629,
#  'precision': 0.006289308176100629,
#  'Ukrainian': 0.006289308176100629,
#  'forces': 0.006289308176100629,
#  'respond': 0.006289308176100629,
#  'platform': 0.006289308176100629,
#  'damage': 0.012578616352201259,
#  'assessment': 0.006289308176100629,
#  'key': 0.006289308176100629,
#  'affected': 0.006289308176100629,
#  'rapidly': 0.006289308176100629,
#  'analyzed': 0.006289308176100629,
#  '2,000': 0.006289308176100629,
#  'square': 0.006289308176100629,
#  'kilometers': 0.006289308176100629,
#  'identifying': 0.006289308176100629,
#  '370,000': 0.006289308176100629,
#  'structures': 0.006289308176100629,
#  'thousands': 0.006289308176100629,
#  'previously': 0.006289308176100629,
#  'available': 0.012578616352201259,
#  'focused': 0.006289308176100629,
#  'Kharkiv': 0.006289308176100629,
#  'Dnipro': 0.006289308176100629,
#  'provided': 0.006289308176100629,
#  'directly': 0.006289308176100629,
#  'government': 0.006289308176100629,
#  'users': 0.006289308176100629,
#  'publicly': 0.006289308176100629,
#  'broader': 0.006289308176100629,
#  'community': 0.006289308176100629,
#  'maximize': 0.006289308176100629,
#  'allocations': 0.006289308176100629,
#  'resources': 0.006289308176100629,
#  'commodities': 0.006289308176100629,
#  'useful': 0.006289308176100629,
#  'types': 0.006289308176100629,
#  'situations': 0.006289308176100629,
#  'Thanks': 0.006289308176100629,
#  'planes': 0.006289308176100629,
#  'moved': 0.006289308176100629,
#  'place': 0.006289308176100629,
#  'called': 0.006289308176100629,
#  'detection': 0.006289308176100629,
#  'Algorithms': 0.006289308176100629,
#  'constantly': 0.006289308176100629,
#  'monitoring': 0.006289308176100629,
#  'kind': 0.006289308176100629,
#  'notices': 0.006289308176100629,
#  'movement': 0.006289308176100629,
#  'alert': 0.006289308176100629,
#  'investigate': 0.006289308176100629,
#  'known': 0.006289308176100629,
#  'predictive': 0.006289308176100629,
#  'modeling': 0.006289308176100629,
#  'economic': 0.006289308176100629,
#  'track': 0.006289308176100629,
#  'farmland': 0.006289308176100629,
#  'measure': 0.006289308176100629,
#  'agricultural': 0.006289308176100629,
#  'major': 0.006289308176100629,
#  'supplier': 0.006289308176100629,
#  'Understanding': 0.006289308176100629,
#  'absolutely': 0.006289308176100629,
#  'conclusion': 0.006289308176100629,
#  'feared': 0.006289308176100629,
#  'tool': 0.006289308176100629,
#  'better': 0.03773584905660377,
#  '…': 0.006289308176100629,
#  'understood': 0.006289308176100629,
#  'transform': 0.006289308176100629,
#  'enables': 0.006289308176100629,
#  'sense': 0.006289308176100629,
#  'amounts': 0.006289308176100629,
#  'historically': 0.006289308176100629,
#  'capacity': 0.006289308176100629,
#  'allows': 0.018867924528301886,
#  'add': 0.006289308176100629,
#  'Areas': 0.006289308176100629,
#  'agriculture': 0.006289308176100629,
#  'best': 0.006289308176100629,
#  'information': 0.006289308176100629,
#  'sensitivity': 0.006289308176100629,
#  'strategize': 0.006289308176100629,
#  'act': 0.006289308176100629,
#  'timely': 0.006289308176100629,
#  'manner': 0.006289308176100629,
#  'makes': 0.006289308176100629,
#  'frees': 0.006289308176100629,
#  'explore': 0.006289308176100629,
#  'fresher': 0.006289308176100629,
#  'newer': 0.006289308176100629,
#  'creative': 0.006289308176100629,
#  'idea': 0.006289308176100629,
#  'driven': 0.006289308176100629,
#  'personally': 0.006289308176100629,
#  'incredibly': 0.006289308176100629,
#  'exciting': 0.006289308176100629,
#  'embrace': 0.006289308176100629,
#  'generative': 0.006289308176100629,
#  'aspects': 0.006289308176100629,
#  'nature': 0.006289308176100629,
#  'run': 0.006289308176100629,
#  'solutions': 0.006289308176100629,
#  'biggest': 0.006289308176100629,
#  'believe': 0.006289308176100629,
#  'led': 0.012578616352201259,
#  'path': 0.006289308176100629,
#  'forward': 0.006289308176100629,
#  'usher': 0.006289308176100629,
#  'Thank': 0.006289308176100629,
#  'Applause': 0.006289308176100629}

# %% [markdown]
# ### Task 8: Calculate Score of Sentences

# %%
sentence_tokens = [sentence for sentence in document.sents]
sentence_score = {}
for sentence in sentence_tokens:
    for word in sentence:
        if word.text.lower() in word_frequencies.keys():
            if sentence not in sentence_score.keys():
                sentence_score[sentence] = word_frequencies[word.text.lower()]
            else:
                sentence_score[sentence] += word_frequencies[word.text.lower()]
sentence_score
# Out:
# { Transcriber: Reihaneh Iranmanesh
#  Reviewer: Elisabeth Buffard: 1.0188679245283019,
#  When most people think about AI, they picture a sci-fi dystopian future,
#  with man versus machine.: 1.1132075471698113,
#  Terminator, Skynet, Black Mirror,
#  Blade Runner, Westworld.: 1.0125786163522013,
#  But as someone who is working on the most ambitious
#  AI projects in the world, every day, I can tell you
#  that is far from reality.: 2.106918238993711,
#  To me, it’s the contrary of that.: 0.006289308176100629,
#  AI enhances
#  and even supercharges humanity.: 1.0377358490566038,
#  Let me explain why.: 0.006289308176100629,
#  There are many reasons
#  why AI will never replace humans.: 1.10062893081761,
#  AI always has,
#  and always will, rely on humans.: 1.0880503144654088,
#  That’s one of the reasons that I was actually inspired
#  to start an AI company.: 1.0628930817610063,
#  That and my background
#  have had a huge impact on me and why I started Scale.: 1.0440251572327044,
#  My parents were brilliant scientists
#  of Los Alamos, who accomplished a lot
#  in advancing their field.: 2.056603773584906,
#  That inspired me to use
#  science and technology to have a real impact on the world.: 1.150943396226415,
#  My dad was a physicist,
#  and my mom was an astrophysicist, both at the top of their field, who made meaningful contributions
#  to plasma fluid dynamics and the beginnings of the universe.: 2.1006289308176114,
#  Their scientific work will have
#  meaningful impact on how we understand
#  and perceive our world.: 2.157232704402516,
#  And I wanted to work
#  on something as impactful or even more impactful than that.: 1.0566037735849056,
#  That’s why I decide
#  to become a programmer, so I can make a difference in the world.: 1.069182389937107,
#  Growing up as a programmer, despite how powerful computers are, you quickly realize
#  how limited they are.: 1.10062893081761,
#  In particular, they lack
#  judgment and intelligence.: 1.0628930817610063,
#  Programming is the art
#  of giving clear robotic instructions to computers to accomplish
#  simple objectives.: 2.081761006289309,
#  It’s all black and white,
#  and there’s no gray area.: 1.0440251572327044,
#  As I learned about AI,
#  it was clearly transformational.: 1.0188679245283019,
#  It changed the game.: 0.012578616352201259,
#  It equipped computers with intelligence,
#  and I knew I wanted to be deeply involved.: 1.0880503144654088,
#  I was studying AI at MIT and slowly
#  became more and more excited about all the potential applications of AI
#  for solving more nuanced problems.: 2.0880503144654092,
#  For example, there was one class project where I worked on applying AI
#  to human emotions.: 1.1761006289308176,
#  The goal was to take picture
#  of human expressions and ultimately identify and understand
#  the emotion through very subtle signals in facial expressions.: 2.245283018867925,
#  Using AI, we built an algorithm that was able to detect intent
#  with 80% accuracy and efficacy.: 1.0628930817610063,
#  We were extremely proud of that.: 0.031446540880503145,
#  It was the start of using AI to do
#  entirely new things using computers.: 1.0817610062893082,
#  That’s when I realize
#  the implications of AI and how it could tackle the gray areas
#  that involve judgment or intelligence.: 2.106918238993711,
#  You see, AI needs humans
#  to teach it individual values, nudge it to find thoughtful outcomes, and ensure that human intentions
#  and values are aligned with the AI.: 2.415094339622642,
#  It was a revelation.: 0.006289308176100629,
#  Before, coding was like
#  a black-and-white film versus watching in technicolor.: 1.0754716981132075,
#  What’s more, AI has the potential
#  to take away the repetition in our lives, meaning that new and fresh ideas
#  will matter more and ultimately enable us to be more human.: 2.264150943396227,
#  But, to power AI,
#  you need powerful data, which was especially hard to come by
#  at that time, in 2016, while I was at MIT.: 2.3396226415094343,
#  I realized that nobody was building
#  anything with AI outside of school.: 1.0880503144654088,
#  It’s unusual for MIT students
#  to not be building something.: 1.069182389937107,
#  Mechanical engineering majors
#  are building catapults in the lawn, electrical engineering majors
#  are building robots, and computer science majors are building
#  apps for their friends to use.: 3.345911949685536,
#  But nobody was building
#  anything using AI.: 1.0566037735849056,
#  That’s when I discovered what
#  a bottleneck data can be to building meaningful
#  and powerful AI systems.: 2.3270440251572326,
#  You can't treat data as an afterthought.: 0.20754716981132076,
#  Bad data or lack of data
#  results in bad AI.: 1.427672955974843,
#  I even realize this in my personal life.: 0.031446540880503145,
#  I put a camera inside my fridge
#  to gather data, to tell me when to refill my groceries
#  and what I needed to buy.: 2.270440251572327,
#  That’s when I realized
#  just how much data I needed to actually be able
#  to successfully predict what to purchase.: 2.2893081761006293,
#  There’s no way I could create enough data to be successful
#  with the algorithms on my own.: 1.2578616352201257,
#  But it did help me discover
#  that my roommate was stealing my food.: 1.0628930817610063,
#  At that point, I realized that this was going to be
#  a pivotal problem for AI.: 1.0440251572327044,
#  Building large-scale,
#  high-quality datasets to power every single application.: 1.1320754716981132,
#  This was the impetus
#  behind starting Scale: quality data, to create
#  reliable AI outcomes, requires human insight and guidance.: 2.4213836477987427,
#  If you think about the core setup of AI,
#  the algorithms need data, and data needs humans.: 1.572327044025157,
#  To ensure data is accurate, an expert human is often required.: 0.3584905660377359,
#  Only humans can understand
#  the context and nuance to properly annotate
#  the data to be fed to algorithms.: 2.3836477987421385,
#  Humans are the one who teach
#  the algorithms what to do.: 1.1257861635220126,
#  They’re the ones making the decisions,
#  they guide them.: 1.0440251572327044,
#  If something happens,
#  here’s what you should do.: 1.0062893081761006,
#  And AI learns from that
#  and replicates it.: 1.0125786163522013,
#  We are teaching the AI
#  our individual values and nudging the AI
#  to find thoughtful outcomes.: 2.119496855345912,
#  Machines make mistakes.: 0.006289308176100629,
#  We have to teach them and
#  incentivize them to tell the truth.: 1.050314465408805,
#  This is why teaching the AI human
#  intentions and values is so important.: 1.1823899371069182,
#  It’s through this process
#  that we will ensure that AI will have fair, ethical outcomes
#  in line with human values.: 2.2389937106918243,
#  It’s this alignment
#  that we must solve for.: 1.0251572327044025,
#  The constant alignment of AI to human
#  intentions will always require humans.: 1.251572327044025,
#  and human ideas and creativity
#  can actually matter much more, with the power of AI behind them.: 1.20125786163522,
#  The long tale of real-world problems, and the fact that there’s always
#  unknown unknowns means that humans
#  will never be fully removed from the AI development lifecycle.: 2.2389937106918243,
#  For example, I remember back in 2016 when chatbots were first starting
#  to become a big thing.: 1.10062893081761,
#  It was right when we were starting Scale.: 0.0440251572327044,
#  We were all thinking there's no way
#  to build a fully automated system.: 1.0754716981132075,
#  There’re so many different conversations
#  that can have so many different pathways.: 1.050314465408805,
#  It’s hard to build AI systems that can
#  properly handle all these possibilities.: 1.0880503144654088,
#  For chatbots to work, there’re humans
#  behind it who make the decisions once, and from there, the chatbots
#  can replicate that over and over again.: 2.1635220125786163,
#  That’s again why it’s impossible
#  for AI to improve or change without human input.: 1.1572327044025157,
#  Let’s take you to the front lines of AI.: 0.006289308176100629,
#  The things that AI automates first
#  are not what you might expect.: 1.0314465408805031,
#  An unintuitive example is the weather.: 0.06289308176100629,
#  Humans have tried for many millennia to crack the code
#  of how to predict the weather.: 1.1446540880503144,
#  It’s especially hard for meteorologists because there are
#  so many different small things that can cause massive impacts
#  on the weather.: 2.1446540880503147,
#  It's the butterfly effect.: 0.012578616352201259,
#  Different elements react to one another
#  in unexpected ways.: 1.0440251572327044,
#  There’re so many inputs
#  that affect the weather, way more data than any person
#  would be able to comprehend on their own.: 2.2830188679245285,
#  That’s why we need AI
#  to analyze the vast oceans of data and provide more accurate, nuanced,
#  and comprehensive analysis.: 2.3081761006289314,
#  At the moment, AI can already provide extremely accurate
#  short-term predictions, including for critical storms and floods.: 1.1132075471698113,
#  So, it’s not what humans perceive
#  to be the simplest task that AI will automate first,
#  but rather where we have the most data.: 2.314465408805032,
#  The use cases the brightest minds
#  are focusing on are much more positive
#  than what you might think.: 2.1069182389937104,
#  That’s again why I think AI
#  will be a supercharger for humanity.: 1.0628930817610063,
#  Unlike the movies, AI developers
#  aren’t focusing their attention on building replacements for humans.: 1.1823899371069182,
#  They’re building tools
#  to help free up our time and energy to focus on what human
#  can uniquely solve.: 2.2830188679245285,
#  A good example about how AI
#  can be used in practice is health care.: 1.0817610062893082,
#  According to the Association
#  of American Medical Colleges, the United States could see
#  an estimated shortage of between 38,000
#  and 124,000 physicians by 2034.: 3.037735849056605,
#  AI could save doctors’ time
#  with rogue tasks and ultimately enable them to serve
#  more patients and help more people.: 2.182389937106919,
#  Health care is full of repetitive tasks
#  which are right for AI.: 1.0817610062893082,
#  When a patient is sick,
#  they go through all kinds of tests which produce all sorts of data:
#  blood tests, imagery, lab results, X-rays, etc.: 2.308176100628932,
#  Doctors then analyze all this data
#  to make decisions about a case.: 1.2641509433962264,
#  AI can analyze all this data proactively and go through a list of possibilities by cross-referencing
#  against all prior data in cases.: 1.471698113207547,
#  It can identify when something isn’t right
#  long before a physician can and flag it to a physician,
#  if it requires more attention.: 2.10062893081761,
#  With AI,
#  doctors are still integral to the process, but it takes less time to get a diagnosis.: 1.10062893081761,
#  You have to wait several weeks for your case to go
#  from one doctor to another.: 1.0314465408805031,
#  The AI will supercharge,
#  finding a diagnosis faster.: 1.0440251572327044,
#  Similarly, in the field of drug discovery,
#  it’s all about using complex data: experiment data, patient data, protein simulations and far more to guide a more efficient process of solving diseas
#  through new drugs and compounds.: 2.767295597484277,
#  Recent advancements in AI have dramatically sped up
#  the scientific process by allowing us to process and make us
#  of more  data than ever before.: 2.3207547169811322,
#  Another good example, and potentially
#  more concrete, is the Russia-Ukraine war.: 1.0754716981132075,
#  We've all seen the images of tanks
#  lining up ready to enter Kiev.: 1.0440251572327044,
#  AI can help assess satellite imagery
#  with superhuman speed and precision, so Ukrainian forces can respond faster.: 1.119496855345912,
#  At Scale, we’re using our platform
#  to do damage assessment in key areas affected by the war.: 1.0754716981132075,
#  We’ve rapidly analyzed
#  over 2,000 square kilometers of Ukraine, identifying over 370,000 structures, including thousands not previously
#  available via other datasets.: 2.10062893081761,
#  We focused on Kiev, Kharkiv and Dnipro, in which we provided some data
#  directly to government and users.: 1.2264150943396226,
#  We also made the data publicly available
#  to the broader AI community via Scale.: 1.2327044025157232,
#  We can also use this data
#  to  maximize allocations of resources, people or commodities.: 1.2955974842767295,
#  It’s clear satellite data
#  can be extremely useful in these types of situations.: 1.2641509433962264,
#  Thanks to satellite data,
#  AI can analyze if planes or tanks have been moved from one place to another.: 1.270440251572327,
#  This is called change detection.: 0.031446540880503145,
#  Algorithms can constantly be monitoring
#  for this kind of data, and if it notices a change or movement, it will alert a human
#  to further investigate, otherwise known as predictive modeling.: 2.4150943396226423,
#  AI can also help us understand
#  the economic impacts of war.: 1.1069182389937107,
#  We can use AI to track
#  farmland in Ukraine and measure the agricultural damage
#  in real time.: 2.125786163522013,
#  Ukraine is a major food supplier
#  for much of the world.: 1.069182389937107,
#  Understanding these impacts
#  is absolutely critical.: 1.0377358490566038,
#  In conclusion, AI is not
#  something to be feared, but it’s a tool that can be used
#  to better understand… that needs to be better understood, and has the potential
#  to transform our lives for the better.: 3.2327044025157248,
#  AI enables us to make use and sense
#  of massive amounts of data that has historically been
#  beyond human capacity.: 2.3899371069182394,
#  It allows us to add
#  intelligence and nuance to automated systems
#  that will dramatically improve humanity.: 2.1446540880503147,
#  Areas like health care and agriculture.: 0.06289308176100629,
#  This then allows humans
#  to do what they do best.: 1.1069182389937107,
#  Take this information,
#  put it into context with sensitivity, to strategize and act in a timely manner.: 1.050314465408805,
#  AI is a supercharger for humanity.: 0.03773584905660378,
#  When AI is better than humans, it makes humans better.: 0.24528301886792453,
#  AI will automate repetitive tasks that don’t require
#  constant human judgment or creativity, which frees us up to explore
#  and focus on fresher, newer ideas.: 2.276729559748428,
#  AI will enable us to be
#  even more creative and more idea-driven, which I personally find
#  incredibly exciting.: 2.075471698113208,
#  It allows us to embrace
#  the generative aspects of human nature, so we can run faster with ideas and build better
#  and more powerful solutions to the world’s biggest problems.: 2.3647798742138373,
#  That’s why I believe
#  that human-led AI is the path forward, and I’m proud to usher all of us
#  into a future with human-led AI.: 2.30188679245283}

# %% [markdown]
# ### Task 9: Generate the Summary

# %%
select_length = int(len(sentence_tokens) * 0.3)
summary = nlargest(select_length, sentence_score, key = sentence_score.get)
final_summary = [word.text for word in summary]
summary = ' '.join(final_summary)
summary
# Out:
# 'Mechanical engineering majors\nare building catapults in the lawn, electrical engineering majors \nare building robots, and computer science majors are building\napps for their friends to use. In conclusion, AI is not\nsomething to be feared, but it’s a tool that can be used\nto better understand… that needs to be better understood, and has the potential\nto transform our lives for the better. According to the Association\nof American Medical Colleges, the United States could see\nan estimated shortage of between 38,000\nand 124,000 physicians by 2034. Similarly, in the field of drug discovery,\nit’s all about using complex data: experiment data, patient data, protein simulations and far more to guide a more efficient process of solving diseas\nthrough new drugs and compounds. This was the impetus\nbehind starting Scale: quality data, to create\nreliable AI outcomes, requires human insight and guidance. Algorithms can constantly be monitoring\nfor this kind of data, and if it notices a change or movement, it will alert a human\nto further investigate, otherwise known as predictive modeling. You see, AI needs humans\nto teach it individual values, nudge it to find thoughtful outcomes, and ensure that human intentions\nand values are aligned with the AI. AI enables us to make use and sense\nof massive amounts of data that has historically been\nbeyond human capacity. Only humans can understand\nthe context and nuance to properly annotate\nthe data to be fed to algorithms. It allows us to embrace\nthe generative aspects of human nature, so we can run faster with ideas and build better\nand more powerful solutions to the world’s biggest problems. But, to power AI,\nyou need powerful data, which was especially hard to come by\nat that time, in 2016, while I was at MIT. That’s when I discovered what\na bottleneck data can be to building meaningful\nand powerful AI systems. Recent advancements in AI have dramatically sped up\nthe scientific process by allowing us to process and make us\nof more  data than ever before. So, it’s not what humans perceive\nto be the simplest task that AI will automate first,\nbut rather where we have the most data. When a patient is sick,\nthey go through all kinds of tests which produce all sorts of data:\nblood tests, imagery, lab results, X-rays, etc. That’s why we need AI\nto analyze the vast oceans of data and provide more accurate, nuanced,\nand comprehensive analysis. That’s why I believe\nthat human-led AI is the path forward, and I’m proud to usher all of us\ninto a future with human-led AI. That’s when I realized\njust how much data I needed to actually be able\nto successfully predict what to purchase. There’re so many inputs\nthat affect the weather, way more data than any person\nwould be able to comprehend on their own. They’re building tools\nto help free up our time and energy to focus on what human\ncan uniquely solve. AI will automate repetitive tasks that don’t require\nconstant human judgment or creativity, which frees us up to explore\nand focus on fresher, newer ideas. I put a camera inside my fridge\nto gather data, to tell me when to refill my groceries\nand what I needed to buy. What’s more, AI has the potential\nto take away the repetition in our lives, meaning that new and fresh ideas\nwill matter more and ultimately enable us to be more human. The goal was to take picture\nof human expressions and ultimately identify and understand\nthe emotion through very subtle signals in facial expressions. It’s through this process\nthat we will ensure that AI will have fair, ethical outcomes\nin line with human values. The long tale of real-world problems, and the fact that there’s always\nunknown unknowns means that humans\nwill never be fully removed from the AI development lifecycle. AI could save doctors’ time\nwith rogue tasks and ultimately enable them to serve\nmore patients and help more people. For chatbots to work, there’re humans\nbehind it who make the decisions once, and fr ...
