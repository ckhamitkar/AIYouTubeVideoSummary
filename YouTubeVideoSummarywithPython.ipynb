# %% [markdown]
# ### Task 1: Import Modules

# %%
from pytube import extract
from heapq import nlargest
from youtube_transcript_api import YouTubeTranscriptApi
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %% [markdown]
# ### Task 2: Get ID of the Youtube Video

# %%
url = 'https://www.youtube.com/watch?v=XyQ76_5uQcU'
video_id = extract.video_id(url)
video_id
# Out:
# 'XyQ76_5uQcU'

# %% [markdown]
# ### Task 3: Get Transcript of Video

# %%
transcript = YouTubeTranscriptApi.get_transcript(video_id)
text = ""
for elem in transcript:
    text = text + " " + elem["text"]
text
# Out:
# ' Otherwise known as the “Gray Ghost,” there’s\xa0\nalways been a sense of mystery with these dogs. In fact, there’s probably a lot of\xa0\nthings you didn’t know about these dogs. Like did you know they’re\xa0\none of the most intelligent\xa0\xa0 and clever dog breeds in the canine kingdom? Interested in learning what behavior\xa0\nis specific to the Weimaraner breed? Or how Weimaraners specialized\xa0\nin tracking down missile parts? If questions like these intrigue you,\xa0\nstick around! In today’s episode,\xa0\xa0 we’re counting down the 10 little known\xa0\nWeimaraner facts that you didn’t know. But before we dive in, hit that\xa0\nsubscribe button and notification bell\xa0\xa0 for more incredible dog facts like these. And hit that “like” button if\xa0\nyou want more Weimaraner videos. Number ten: Some Weimaraners\xa0\nhave “tiny horns” on their heads. No, we’re not saying that\xa0\nthese mischievous playful\xa0\xa0 dogs are little devils - though\xa0\nthey can act like one at times. And we’re also not talking about the typical\xa0\n“horns” that you see on rhinos, cattle or goats. Rather, there are some Weimaraners who have a tiny\xa0\xa0 flap of skin that sits on their\xa0\nhead, right above their ears. But not all Weimaraners have this, of course. It’s believed that dogs with these “little\xa0\xa0 horns” were descended from the\xa0\nHarrasburg line of Weimaraners. In fact, it’s why they’re frequently\xa0\nknown as the “Harrasburg Horns.” However, Weimaraners aren’t exactly\xa0\nspecial with this set of horns. Similar breeds, such as the Vizsla and German\xa0\nShorthaired Pointer, both have these horns, too. So, did you check your dog? Do they have\xa0\xa0 the Harrasburg Horns? Let us\xa0\nknow in the comments below! Number nine: Only Weimaraners are born\xa0\nwith this unique physical characteristic. Dog breeds that have unique coats are\xa0\noften born with a simple and plain coat. For example, the spotted Dalmatians don’t\xa0\nactually have their spots as a newborn puppy. And the Blue Heeler’s unique coats are actually\xa0\nsolid white when they first arrive in this world. However, the Weimaraner is the opposite. Instead of their solid-colored coats,\xa0\xa0 Weimaraners are actually born with tiger\xa0\nstripes that streak through their entire bodies. And while this looks amazing,\xa0\nit doesn’t last very long. In just a few days, these tiger stripes start to\xa0\nfade and the solid gray coats start to emerge. But stripes aren’t the only cool\xa0\nthing about a Weimaraner puppy. These dogs are also born\xa0\nwith bright, light-blue eyes. As the dog ages, the blue gradually\xa0\nturns into a gray or amber color. Number eight: They’re nicknamed the\xa0\n“dog with the human brain” for a reason. Did you know that Weimaraners are some of the\xa0\nsmartest and most clever dogs in the world? They’re so intelligent that they’ve apparently\xa0\xa0 earned themselves the nickname,\xa0\n“dog with the human brain.” But just how intelligent are they? For obedience and working intelligence,\xa0\nWeimaraners are the 25th smartest dogs. This essentially means that Weimaraners can learn\xa0\na new command with just 5 to 15 repetitions. Plus, they’re able to obey a known command, on the\xa0\nfirst attempt, with a 85% or better success rate! But what ultimately landed them the title of “dog\xa0\xa0 with a human brain” isn’t from\xa0\ntheir obedience and working IQ. Rather, it’s from their\xa0\nfreakishly high adaptive IQ. This type of dog intelligence refers\xa0\nto what the dog can learn for himself. Weimaraners are clever dogs that are great at\xa0\nlearning from previous mistakes and experiences. Plus, they’re some of the best\xa0\nproblem solvers in the canine kingdom. So does this sound like your Weimaraner?\xa0\nLet us know in the comments below! Number seven: They’re one of the\xa0\nfastest dog breeds ever on land. Weimaraners are fast dogs. After all, they were bred to hunt small and\xa0\nagile animals, such as rabbits, foxes a ...

# %% [markdown]
# ### Task 4: Get all Sentences

# %%
nlp = spacy.load('en_core_web_sm')
document = nlp(text)
for sentence in document.sents:
    print(sentence.text)
# Out:
#  Otherwise known as the “Gray Ghost,” there’s
# always been a sense of mystery with these dogs.
# In fact, there’s probably a lot of
# things you didn’t know about these dogs.
# Like did you know they’re
# one of the most intelligent   and clever dog breeds in the canine kingdom?
# Interested in learning what behavior
# is specific to the Weimaraner breed?
# Or how Weimaraners specialized
# in tracking down missile parts?
# If questions like these intrigue you,
# stick around!
# In today’s episode,   we’re counting down the 10 little known
# Weimaraner facts that you didn’t know.
# But before we dive in, hit that
# subscribe button and notification bell   for more incredible dog facts like these.
# And hit that “like” button if
# you want more Weimaraner videos.
# Number ten: Some Weimaraners
# have “tiny horns” on their heads.
# No, we’re not saying that
# these mischievous playful   dogs are little devils - though
# they can act like one at times.
# And we’re also not talking about the typical
# “horns” that you see on rhinos, cattle or goats.
# Rather, there are some Weimaraners who have a tiny   flap of skin that sits on their
# head, right above their ears.
# But not all Weimaraners have this, of course.
# It’s believed that dogs with these “little   horns” were descended from the
# Harrasburg line of Weimaraners.
# In fact, it’s why they’re frequently
# known as the “Harrasburg Horns.”
# However, Weimaraners aren’t exactly
# special with this set of horns.
# Similar breeds, such as the Vizsla and German
# Shorthaired Pointer, both have these horns, too.
# So, did you check your dog?
# Do they have   the Harrasburg Horns?
# Let us
# know in the comments below!
# Number nine: Only Weimaraners are born
# with this unique physical characteristic.
# Dog breeds that have unique coats are
# often born with a simple and plain coat.
# For example, the spotted Dalmatians don’t
# actually have their spots as a newborn puppy.
# And the Blue Heeler’s unique coats are actually
# solid white when they first arrive in this world.
# However, the Weimaraner is the opposite.
# Instead of their solid-colored coats,   Weimaraners are actually born with tiger
# stripes that streak through their entire bodies.
# And while this looks amazing,
# it doesn’t last very long.
# In just a few days, these tiger stripes start to
# fade and the solid gray coats start to emerge.
# But stripes aren’t the only cool
# thing about a Weimaraner puppy.
# These dogs are also born
# with bright, light-blue eyes.
# As the dog ages, the blue gradually
# turns into a gray or amber color.
# Number eight: They’re nicknamed the
# “dog with the human brain” for a reason.
# Did you know that Weimaraners are some of the
# smartest and most clever dogs in the world?
# They’re so intelligent that they’ve apparently   earned themselves the nickname,
# “dog with the human brain.”
# But just how intelligent are they?
# For obedience and working intelligence,
# Weimaraners are the 25th smartest dogs.
# This essentially means that Weimaraners can learn
# a new command with just 5 to 15 repetitions.
# Plus, they’re able to obey a known command, on the
# first attempt, with a 85% or better success rate!
# But what ultimately landed them the title of “dog   with a human brain” isn’t from
# their obedience and working IQ.
# Rather, it’s from their
# freakishly high adaptive IQ.
# This type of dog intelligence refers
# to what the dog can learn for himself.
# Weimaraners are clever dogs that are great at
# learning from previous mistakes and experiences.
# Plus, they’re some of the best
# problem solvers in the canine kingdom.
# So does this sound like your Weimaraner?
#
# Let us know in the comments below!
# Number seven: They’re one of the
# fastest dog breeds ever on land.
# Weimaraners are fast dogs.
# After all, they were bred to hunt small and
# agile animals, such as rabbits, foxes and fowl.
# But just how fast are they?
# According to Parade.com, the Weimaraner
# can run a remarkable 35 miles per hour!
# For reference, the world’s fastest
# horse runs about 55 miles per hour.
# And the world’s fastest dog, the Greyhound,
# can reach 45 miles per hour in full stride.
# All in all, the top speed of the Weimaraner makes
# them one of the 10 fastest dog breeds alive.
# Number six: A Weimaraner and his owner set the
# world record for fastest mile time in 2016.
# How do we know these dogs are some of the fastest?
# Well, we have some proof
# to back up that statement.
# In 2016, a man and his furry companion broke the   unofficial record for the “human-dog
# mile” in Santa Barbara, California.
# This race is essentially a dog on a leash,
# while the human and dog run a single mile.
# The dog named “Kaydom,”
# was a 5 year old Weimaraner   who the owner rescued from
# a shelter 3 years prior.
# Since then, they’ve been logging in
# 40 miles per week as running buddies.
# So it’s not surprising that
# Kaydom and his owner blazed   through the mile in just 4 minutes and 13 seconds.
# And according to the 39 year old owner,
# Brian Duff, he was just trying to run as   fast as he could to keep up with
# Kaydom through the mile-long run.
# Who knew these dogs had it in them?
# Number five: Out of all the AKC breed standards,   only the Weimaraner’s breed
# standard has this unusual word.
# Official AKC breed standards can
# tell you a lot about a dog breed.
# And oftentimes, you’ll find words
# that seem to perfectly fit the bill.
# For example, only 4 breed standards
# include the word “majestic.”
# One of which is the calm
# and magnificent Cane Corso.
# But did you know that the Weimaraner’s breed   standard is the only standard
# to include the word “trumpet?”
# And no, they’re not describing
# the brass instrument.
# Instead, the word “trumpet” actually refers to
# the protruding temples on the Weimaraner’s head.
# It’s pretty much the spot behind the
# eye socket of the side of the skull.
# And while we still have no idea why the word
# “trumpet” was used to describe this trait,   we do know that “trumpets” are a beautiful
# complement to their facial features.
# Number four: There’s an unusual behavior
# that’s often seen in the Weimaraner breed.
# Does your Weimaraner “nook?”
# If you don’t actually own one of these
# dogs, then it’s okay to be confused.
# Nooking refers to the behavior where the
# dog kneads and sucks on their stuffed toys.
# We still don’t have a full explanation for this,   but some believe that it’s caused by
# early separation from their mothers.
# Others believe that it’s just a
# thing Weimaraners do for comfort.
# And although some say that this trait
# is seen specifically in Weimaraners,   it appears that it’s not exclusive to this breed.
# It’s just that Weimaraners show this
# behavior far more often than any other breed.
# Number three: US President Eisenhower’s Weimaraner
# was a huge hit with the people of America.
# Of all the celebrities that
# have owned a Weimaraner,   ex US President Dwight D. Eisenhower
# may be the most famous of them all.
# His Weimaraner’s name was Heidi, and she was a
# personality that people couldn’t get enough of.
# When media photographers tried to snap pictures
# of the First Lady, Heidi would lunge at them.
# Newspapers would write all sorts
# of ridiculous stories about Heidi.
# For instance, one reporter stated that
# she ate two poached eggs on toast,   along with bacon, for breakfast every single day.
# Others reported that her meals consisted of
# cooked ground beef mixed together with kibbles.
# And finally, there was the rug
# incident, where Heidi’s bladder   failed on a 20 thousand dollar rug in
# one of the White House reception rooms!
# Since then, Heidi moved away
# from the spotlight and lived   peacefully at the Eisenhower farm in Pennsylvania.
# Number two:
# One heroic Weimaraner entered the
# Animal Hall of Fame for saving his owner’s life.
# Not only are dogs great companions
# and friends, but oftentimes they’ve   even saved their owners’ lives.
#
# We’ve heard of these heroic   stories time and time again.
#
# And on Easter Sunday in 2007,   a Weimaraner named Herman Jr did it again.
#
# Herman’s owner got up in the middle of the night   feeling ill, so he decided to go for a walk around
# the house and watch some late-night television.
# In a sudden, the owner collapsed and couldn’t
# move while struggling to cry for help.
# Herman took notice and immediately
# ran upstairs to wake up his wife.
# The wife woke up and, when she
# found her husband, called 911.
# It was a 100-percent blockage of the coronary
# artery, which has just a 50% survival rate.
# Without the quick actions of Herman
# Jr, his owner may not be alive today.
# Two years later, the heroic
# Weimaraner was inducted into   Iowa’s Animal Hall of Fame, and rightfully so.
# Number one: During the Cold War, one Weimaraner
# specialized in locating the most unusual thing.
# One of the most impressive qualities of the   Weimaraner is the nose and as a
# result, the keen sense of smell.
# It’s why they make excellent tracking
# dogs for small game and missing people.
# But during the Cold War, there was one Weimaraner
# that specialized in tracking missile fragments.
# Dingo was his name.
# And Dingo, along with his German Shorthaired
# pointer friend, were crucial in recovering   pieces of missiles so scientists could study
# the success or failure of these missiles.
# The team of dogs worked hard
# everyday no matter the weather.
# In fact, in the intense heat,
# these dogs were given a custom   terry-cloth jacket with pockets to
# hold ice cubes as a way to cool down.
# These dogs had a 96% recovery rate,
# and the program was so successful   that numerous military and research
# agencies wanted the services of these dogs.
# The program eventually ended in 1965,   but Dingo and Count were the first and
# best recovery missile dogs in history.
# So what was your favorite Weimaraner fact?
# Did
# we miss any that deserve to be on this list?
# Let us know in the comments section below.
#
# And if you enjoyed this video,   consider subscribing to The Smart Canine for the
# most interesting stories and facts behind dogs.

# %% [markdown]
# ### Task 5: Get all Tokens from Document

# %%
tokens = [token.text for token in document]
tokens
# Out:
# [' ',
#  'Otherwise',
#  'known',
#  'as',
#  'the',
#  '“',
#  'Gray',
#  'Ghost',
#  ',',
#  '”',
#  'there',
#  '’s',
#  '\xa0\n',
#  'always',
#  'been',
#  'a',
#  'sense',
#  'of',
#  'mystery',
#  'with',
#  'these',
#  'dogs',
#  '.',
#  'In',
#  'fact',
#  ',',
#  'there',
#  '’s',
#  'probably',
#  'a',
#  'lot',
#  'of',
#  '\xa0\n',
#  'things',
#  'you',
#  'did',
#  'n’t',
#  'know',
#  'about',
#  'these',
#  'dogs',
#  '.',
#  'Like',
#  'did',
#  'you',
#  'know',
#  'they',
#  '’re',
#  '\xa0\n',
#  'one',
#  'of',
#  'the',
#  'most',
#  'intelligent',
#  '\xa0\xa0 ',
#  'and',
#  'clever',
#  'dog',
#  'breeds',
#  'in',
#  'the',
#  'canine',
#  'kingdom',
#  '?',
#  'Interested',
#  'in',
#  'learning',
#  'what',
#  'behavior',
#  '\xa0\n',
#  'is',
#  'specific',
#  'to',
#  'the',
#  'Weimaraner',
#  'breed',
#  '?',
#  'Or',
#  'how',
#  'Weimaraners',
#  'specialized',
#  '\xa0\n',
#  'in',
#  'tracking',
#  'down',
#  'missile',
#  'parts',
#  '?',
#  'If',
#  'questions',
#  'like',
#  'these',
#  'intrigue',
#  'you',
#  ',',
#  '\xa0\n',
#  'stick',
#  'around',
#  '!',
#  'In',
#  'today',
#  '’s',
#  'episode',
#  ',',
#  '\xa0\xa0 ',
#  'we',
#  '’re',
#  'counting',
#  'down',
#  'the',
#  '10',
#  'little',
#  'known',
#  '\xa0\n',
#  'Weimaraner',
#  'facts',
#  'that',
#  'you',
#  'did',
#  'n’t',
#  'know',
#  '.',
#  'But',
#  'before',
#  'we',
#  'dive',
#  'in',
#  ',',
#  'hit',
#  'that',
#  '\xa0\n',
#  'subscribe',
#  'button',
#  'and',
#  'notification',
#  'bell',
#  '\xa0\xa0 ',
#  'for',
#  'more',
#  'incredible',
#  'dog',
#  'facts',
#  'like',
#  'these',
#  '.',
#  'And',
#  'hit',
#  'that',
#  '“',
#  'like',
#  '”',
#  'button',
#  'if',
#  '\xa0\n',
#  'you',
#  'want',
#  'more',
#  'Weimaraner',
#  'videos',
#  '.',
#  'Number',
#  'ten',
#  ':',
#  'Some',
#  'Weimaraners',
#  '\xa0\n',
#  'have',
#  '“',
#  'tiny',
#  'horns',
#  '”',
#  'on',
#  'their',
#  'heads',
#  '.',
#  'No',
#  ',',
#  'we',
#  '’re',
#  'not',
#  'saying',
#  'that',
#  '\xa0\n',
#  'these',
#  'mischievous',
#  'playful',
#  '\xa0\xa0 ',
#  'dogs',
#  'are',
#  'little',
#  'devils',
#  '-',
#  'though',
#  '\xa0\n',
#  'they',
#  'can',
#  'act',
#  'like',
#  'one',
#  'at',
#  'times',
#  '.',
#  'And',
#  'we',
#  '’re',
#  'also',
#  'not',
#  'talking',
#  'about',
#  'the',
#  'typical',
#  '\xa0\n',
#  '“',
#  'horns',
#  '”',
#  'that',
#  'you',
#  'see',
#  'on',
#  'rhinos',
#  ',',
#  'cattle',
#  'or',
#  'goats',
#  '.',
#  'Rather',
#  ',',
#  'there',
#  'are',
#  'some',
#  'Weimaraners',
#  'who',
#  'have',
#  'a',
#  'tiny',
#  '\xa0\xa0 ',
#  'flap',
#  'of',
#  'skin',
#  'that',
#  'sits',
#  'on',
#  'their',
#  '\xa0\n',
#  'head',
#  ',',
#  'right',
#  'above',
#  'their',
#  'ears',
#  '.',
#  'But',
#  'not',
#  'all',
#  'Weimaraners',
#  'have',
#  'this',
#  ',',
#  'of',
#  'course',
#  '.',
#  'It',
#  '’s',
#  'believed',
#  'that',
#  'dogs',
#  'with',
#  'these',
#  '“',
#  'little',
#  '\xa0\xa0 ',
#  'horns',
#  '”',
#  'were',
#  'descended',
#  'from',
#  'the',
#  '\xa0\n',
#  'Harrasburg',
#  'line',
#  'of',
#  'Weimaraners',
#  '.',
#  'In',
#  'fact',
#  ',',
#  'it',
#  '’s',
#  'why',
#  'they',
#  '’re',
#  'frequently',
#  '\xa0\n',
#  'known',
#  'as',
#  'the',
#  '“',
#  'Harrasburg',
#  'Horns',
#  '.',
#  '”',
#  'However',
#  ',',
#  'Weimaraners',
#  'are',
#  'n’t',
#  'exactly',
#  '\xa0\n',
#  'special',
#  'with',
#  'this',
#  'set',
#  'of',
#  'horns',
#  '.',
#  'Similar',
#  'breeds',
#  ',',
#  'such',
#  'as',
#  'the',
#  'Vizsla',
#  'and',
#  'German',
#  '\xa0\n',
#  'Shorthaired',
#  'Pointer',
#  ',',
#  'both',
#  'have',
#  'these',
#  'horns',
#  ',',
#  'too',
#  '.',
#  'So',
#  ',',
#  'did',
#  'you',
#  'check',
#  'your',
#  'dog',
#  '?',
#  'Do',
#  'they',
#  'have',
#  '\xa0\xa0 ',
#  'the',
#  'Harrasburg',
#  'Horns',
#  '?',
#  'Let',
#  'us',
#  '\xa0\n',
#  'know',
#  'in',
#  'the',
#  'comments',
#  'below',
#  '!',
#  'Number',
#  'nine',
#  ':',
#  'Only',
#  'Weimaraners',
#  'are',
#  'born',
#  '\xa0\n',
#  'with',
#  'this',
#  'unique',
#  'physical',
#  'characteristic',
#  '.',
#  'Dog',
#  'breeds',
#  'that',
#  'have',
#  'unique',
#  'coats',
#  'are',
#  '\xa0\n',
#  'often',
#  'born',
#  'with',
#  'a',
#  'simple',
#  'and',
#  'plain',
#  'coat',
#  '.',
#  'For',
#  'example',
#  ',',
#  'the',
#  'spotted',
#  'Dalmatians',
#  'do',
#  'n’t',
#  '\xa0\n',
#  'actually',
#  'have',
#  'their',
#  'spots',
#  'as',
#  'a',
#  'newborn',
#  'puppy',
#  '.',
#  'And',
#  'the',
#  'Blue',
#  'Heeler',
#  '’s',
#  'unique',
#  'coats',
#  'are',
#  'actually',
#  '\xa0\n',
#  'solid',
#  'white',
#  'when',
#  'they',
#  'first',
#  'arrive',
#  'in',
#  'this',
#  'world',
#  '.',
#  'However',
#  ',',
#  'the',
#  'Weimaraner',
#  'is',
#  'the',
#  'opposite',
#  '.',
#  'Instead',
#  'of',
#  'their',
#  'solid',
#  '-',
#  'colored',
#  'coats',
#  ',',
#  '\xa0\xa0 ',
#  'Weimaraners',
#  'are',
#  'actually',
#  'born',
#  'with',
#  'tiger',
#  '\xa0\n',
#  'stripes',
#  'that',
#  'streak',
#  'through',
#  'their',
#  'entire',
#  'bodies',
#  '.',
#  'And',
#  'while',
#  'this',
#  'looks',
#  'amazing',
#  ',',
#  '\xa0\n',
#  'it',
#  'does',
#  'n’t',
#  'last',
#  'very',
#  'long',
#  '.',
#  'In',
#  'just',
#  'a',
#  'few',
#  'days',
#  ',',
#  'these',
#  'tiger',
#  'stripes',
#  'start',
#  'to',
#  '\xa0\n',
#  'fade',
#  'and',
#  'the',
#  'solid',
#  'gray',
#  'coats',
#  'start',
#  'to',
#  'emerge',
#  '.',
#  'But',
#  'stripes',
#  'are',
#  'n’t',
#  'the',
#  'only',
#  'cool',
#  '\xa0\n',
#  'thing',
#  'about',
#  'a',
#  'Weimaraner',
#  'puppy',
#  '.',
#  'These',
#  'dogs',
#  'are',
#  'also',
#  'born',
#  '\xa0\n',
#  'with',
#  'bright',
#  ',',
#  'light',
#  '-',
#  'blue',
#  'eyes',
#  '.',
#  'As',
#  'the',
#  'dog',
#  'ages',
#  ',',
#  'the',
#  'blue',
#  'gradually',
#  '\xa0\n',
#  'turns',
#  'into',
#  'a',
#  'gray',
#  'or',
#  'amber',
#  'color',
#  '.',
#  'Number',
#  'eight',
#  ':',
#  'They',
#  '’re',
#  'nicknamed',
#  'the',
#  '\xa0\n',
#  '“',
#  'dog',
#  'with',
#  'the',
#  'human',
#  'brain',
#  '”',
#  'for',
#  'a',
#  'reason',
#  '.',
#  'Did',
#  'you',
#  'know',
#  'that',
#  'Weimaraners',
#  'are',
#  'some',
#  'of',
#  'the',
#  '\xa0\n',
#  'smartest',
#  'and',
#  'most',
#  'clever',
#  'dogs',
#  'in',
#  'the',
#  'world',
#  '?',
#  'They',
#  '’re',
#  'so',
#  'intelligent',
#  'that',
#  'they',
#  '’ve',
#  'apparently',
#  '\xa0\xa0 ',
#  'earned',
#  'themselves',
#  'the',
#  'nickname',
#  ',',
#  '\xa0\n',
#  '“',
#  'dog',
#  'with',
#  'the',
#  'human',
#  'brain',
#  '.',
#  '”',
#  'But',
#  'just',
#  'how',
#  'intelligent',
#  'are',
#  'they',
#  '?',
#  'For',
#  'obedience',
#  'and',
#  'working',
#  'intelligence',
#  ',',
#  '\xa0\n',
#  'Weimaraners',
#  'are',
#  'the',
#  '25th',
#  'smartest',
#  'dogs',
#  '.',
#  'This',
#  'essentially',
#  'means',
#  'that',
#  'Weimaraners',
#  'can',
#  'learn',
#  '\xa0\n',
#  'a',
#  'new',
#  'command',
#  'with',
#  'just',
#  '5',
#  'to',
#  '15',
#  'repetitions',
#  '.',
#  'Plus',
#  ',',
#  'they',
#  '’re',
#  'able',
#  'to',
#  'obey',
#  'a',
#  'known',
#  'command',
#  ',',
#  'on',
#  'the',
#  '\xa0\n',
#  'first',
#  'attempt',
#  ',',
#  'with',
#  'a',
#  '85',
#  '%',
#  'or',
#  'better',
#  'success',
#  'rate',
#  '!',
#  'But',
#  'what',
#  'ultimately',
#  'landed',
#  'them',
#  'the',
#  'title',
#  'of',
#  '“',
#  'dog',
#  '\xa0\xa0 ',
#  'with',
#  'a',
#  'human',
#  'brain',
#  '”',
#  'is',
#  'n’t',
#  'from',
#  '\xa0\n',
#  'their',
#  'obedience',
#  'and',
#  'working',
#  'IQ',
#  '.',
#  'Rather',
#  ',',
#  'it',
#  '’s',
#  'from',
#  'their',
#  '\xa0\n',
#  'freakishly',
#  'high',
#  'adaptive',
#  'IQ',
#  '.',
#  'This',
#  'type',
#  'of',
#  'dog',
#  'intelligence',
#  'refers',
#  '\xa0\n',
#  'to',
#  'what',
#  'the',
#  'dog',
#  'can',
#  'learn',
#  'for',
#  'himself',
#  '.',
#  'Weimaraners',
#  'are',
#  'clever',
#  'dogs',
#  'that',
#  'are',
#  'great',
#  'at',
#  '\xa0\n',
#  'learning',
#  'from',
#  'previous',
#  'mistakes',
#  'and',
#  'experiences',
#  '.',
#  'Plus',
#  ',',
#  'they',
#  '’re',
#  'some',
#  'of',
#  'the',
#  'best',
#  '\xa0\n',
#  'problem',
#  'solvers',
#  'in',
#  'the',
#  'canine',
#  'kingdom',
#  '.',
#  'So',
#  'does',
#  'this',
#  'sound',
#  'like',
#  'your',
#  'Weimaraner',
#  '?',
#  '\xa0\n',
#  'Let',
#  'us',
#  'know',
#  'in',
#  'the',
#  'comments',
#  'below',
#  '!',
#  'Number',
#  'seven',
#  ':',
#  'They',
#  '’re',
#  'one',
#  'of',
#  'the',
#  '\xa0\n',
#  'fastest',
#  'dog',
#  'breeds',
#  'ever',
#  'on',
#  'land',
#  '.',
#  'Weimaraners',
#  'are',
#  'fast',
#  'dogs',
#  '.',
#  'After',
#  'all',
#  ',',
#  'they',
#  'were',
#  'bred',
#  'to',
#  'hunt',
#  'small',
#  'and',
#  '\xa0\n',
#  'agile',
#  'animals',
#  ',',
#  'such',
#  'as',
#  'rabbits',
#  ',',
#  'foxes',
#  'and',
#  'fowl',
#  '.',
#  'But',
#  'just',
#  'how',
#  'fast',
#  'are',
#  'they',
#  '?',
#  'According',
#  'to',
#  'Parade.com',
#  ',',
#  'the',
#  'Weimaraner',
#  '\xa0\n',
#  'can',
#  'run',
#  'a',
#  'remarkable',
#  '35',
#  'miles',
#  'per',
#  'hour',
#  '!',
#  'For',
#  'reference',
#  ',',
#  'the',
#  'world',
#  '’s',
#  'fastest',
#  '\xa0\n',
#  'horse',
#  'runs',
#  'about',
#  '55',
#  'miles',
#  'per',
#  'hour',
#  '.',
#  'And',
#  'the',
#  'world',
#  '’s',
#  'fastest',
#  'dog',
#  ',',
#  'the',
#  'Greyhound',
#  ',',
#  '\xa0\n',
#  'can',
#  'reach',
#  '45',
#  'miles',
#  'per',
#  'hour',
#  'in',
#  'full',
#  'stride',
#  '.',
#  'All',
#  'in',
#  'all',
#  ',',
#  'the',
#  'top',
#  'speed',
#  'of',
#  'the',
#  'Weimaraner',
#  'makes',
#  '\xa0\n',
#  'them',
#  'one',
#  'of',
#  'the',
#  '10',
#  'fastest',
#  'dog',
#  'breeds',
#  'alive',
#  '.',
#  'Number',
#  'six',
#  ':',
#  'A',
#  'Weimaraner',
#  'and',
#  'his',
#  'owner',
#  'set',
#  'the',
#  '\xa0\n',
#  'world',
#  'record',
#  'for',
#  'fastest',
#  'mile',
#  'time',
#  'in',
#  '2016',
#  '.',
#  'How',
#  'do',
#  'we',
#  'know',
#  'these',
#  'dogs',
#  'are',
#  'some',
#  'of',
#  'the',
#  'fastest',
#  '?',
#  'Well',
#  ',',
#  'we',
#  'have',
#  'some',
#  'proof',
#  '\xa0\n',
#  'to',
#  'back',
#  'up',
#  'that',
#  'statement',
#  '.',
#  'In',
#  '2016',
#  ',',
#  'a',
#  'man',
#  'and',
#  'his',
#  'furry',
#  'companion',
#  'broke',
#  'the',
#  '\xa0\xa0 ',
#  'unofficial',
#  'record',
#  'for',
#  'the',
#  '“',
#  'human',
#  '-',
#  'dog',
#  '\xa0\n',
#  'mile',
#  '”',
#  'in',
#  'Santa',
#  'Barbara',
#  ',',
#  'California',
#  '.',
#  'This',
#  'race',
#  'is',
#  'essentially',
#  'a',
#  'dog',
#  'on',
#  'a',
#  'leash',
#  ',',
#  '\xa0\n',
#  'while',
#  'the',
#  'human',
#  'and',
#  'dog',
#  'run',
#  'a',
#  'single',
#  'mile',
#  '.',
#  'The',
#  'dog',
#  'named',
#  '“',
#  'Kaydom',
#  ',',
#  '”',
#  '\xa0\n',
#  'was',
#  ...]

# %% [markdown]
# ### Task 6: Calculate Frequency of Tokens

# %%
word_frequencies = {}
for word in document:
    text = word.text.lower()
    if text not in list(STOP_WORDS) and text not in punctuation:
        if word.text not in word_frequencies.keys():
            word_frequencies[word.text] = 1
        else:
            word_frequencies[word.text] += 1
word_frequencies
# Out:
# {' ': 1,
#  'known': 4,
#  '“': 17,
#  'Gray': 1,
#  'Ghost': 1,
#  '”': 17,
#  '\xa0\n': 109,
#  'sense': 2,
#  'mystery': 1,
#  'dogs': 20,
#  'fact': 4,
#  'probably': 1,
#  'lot': 2,
#  'things': 1,
#  'know': 10,
#  'Like': 1,
#  'intelligent': 3,
#  '\xa0\xa0 ': 36,
#  'clever': 3,
#  'dog': 18,
#  'breeds': 5,
#  'canine': 2,
#  'kingdom': 2,
#  'Interested': 1,
#  'learning': 2,
#  'behavior': 4,
#  'specific': 1,
#  'Weimaraner': 25,
#  'breed': 10,
#  'Weimaraners': 16,
#  'specialized': 3,
#  'tracking': 3,
#  'missile': 3,
#  'parts': 1,
#  'questions': 1,
#  'like': 5,
#  'intrigue': 1,
#  'stick': 1,
#  'today': 2,
#  'episode': 1,
#  'counting': 1,
#  '10': 2,
#  'little': 3,
#  'facts': 3,
#  'dive': 1,
#  'hit': 3,
#  'subscribe': 1,
#  'button': 2,
#  'notification': 1,
#  'bell': 1,
#  'incredible': 1,
#  'want': 1,
#  'videos': 1,
#  'Number': 10,
#  'tiny': 2,
#  'horns': 5,
#  'heads': 1,
#  'saying': 1,
#  'mischievous': 1,
#  'playful': 1,
#  'devils': 1,
#  'act': 1,
#  'times': 1,
#  'talking': 1,
#  'typical': 1,
#  'rhinos': 1,
#  'cattle': 1,
#  'goats': 1,
#  'flap': 1,
#  'skin': 1,
#  'sits': 1,
#  'head': 2,
#  'right': 1,
#  'ears': 1,
#  'course': 1,
#  'believed': 1,
#  'descended': 1,
#  'Harrasburg': 3,
#  'line': 1,
#  'frequently': 1,
#  'Horns': 2,
#  'exactly': 1,
#  'special': 1,
#  'set': 2,
#  'Similar': 1,
#  'Vizsla': 1,
#  'German': 2,
#  'Shorthaired': 2,
#  'Pointer': 1,
#  'check': 1,
#  'Let': 3,
#  'comments': 3,
#  'born': 4,
#  'unique': 3,
#  'physical': 1,
#  'characteristic': 1,
#  'Dog': 1,
#  'coats': 4,
#  'simple': 1,
#  'plain': 1,
#  'coat': 1,
#  'example': 2,
#  'spotted': 1,
#  'Dalmatians': 1,
#  'actually': 5,
#  'spots': 1,
#  'newborn': 1,
#  'puppy': 2,
#  'Blue': 1,
#  'Heeler': 1,
#  'solid': 3,
#  'white': 1,
#  'arrive': 1,
#  'world': 5,
#  'opposite': 1,
#  'Instead': 2,
#  'colored': 1,
#  'tiger': 2,
#  'stripes': 3,
#  'streak': 1,
#  'entire': 1,
#  'bodies': 1,
#  'looks': 1,
#  'amazing': 1,
#  'long': 2,
#  'days': 1,
#  'start': 2,
#  'fade': 1,
#  'gray': 2,
#  'emerge': 1,
#  'cool': 2,
#  'thing': 3,
#  'bright': 1,
#  'light': 1,
#  'blue': 2,
#  'eyes': 1,
#  'ages': 1,
#  'gradually': 1,
#  'turns': 1,
#  'amber': 1,
#  'color': 1,
#  'nicknamed': 1,
#  'human': 5,
#  'brain': 3,
#  'reason': 1,
#  'smartest': 2,
#  'apparently': 1,
#  'earned': 1,
#  'nickname': 1,
#  'obedience': 2,
#  'working': 2,
#  'intelligence': 2,
#  '25th': 1,
#  'essentially': 2,
#  'means': 1,
#  'learn': 2,
#  'new': 1,
#  'command': 2,
#  '5': 2,
#  '15': 1,
#  'repetitions': 1,
#  'Plus': 2,
#  'able': 1,
#  'obey': 1,
#  'attempt': 1,
#  '85': 1,
#  'better': 1,
#  'success': 2,
#  'rate': 3,
#  'ultimately': 1,
#  'landed': 1,
#  'title': 1,
#  'IQ': 2,
#  'freakishly': 1,
#  'high': 1,
#  'adaptive': 1,
#  'type': 1,
#  'refers': 3,
#  'great': 2,
#  'previous': 1,
#  'mistakes': 1,
#  'experiences': 1,
#  'best': 2,
#  'problem': 1,
#  'solvers': 1,
#  'sound': 1,
#  'seven': 1,
#  'fastest': 6,
#  'land': 1,
#  'fast': 3,
#  'bred': 1,
#  'hunt': 1,
#  'small': 2,
#  'agile': 1,
#  'animals': 1,
#  'rabbits': 1,
#  'foxes': 1,
#  'fowl': 1,
#  'According': 1,
#  'Parade.com': 1,
#  'run': 4,
#  'remarkable': 1,
#  '35': 1,
#  'miles': 4,
#  'hour': 3,
#  'reference': 1,
#  'horse': 1,
#  'runs': 1,
#  '55': 1,
#  'Greyhound': 1,
#  'reach': 1,
#  '45': 1,
#  'stride': 1,
#  'speed': 1,
#  'makes': 1,
#  'alive': 2,
#  'owner': 8,
#  'record': 2,
#  'mile': 5,
#  'time': 3,
#  '2016': 2,
#  'proof': 1,
#  'statement': 1,
#  'man': 1,
#  'furry': 1,
#  'companion': 1,
#  'broke': 1,
#  'unofficial': 1,
#  'Santa': 1,
#  'Barbara': 1,
#  'California': 1,
#  'race': 1,
#  'leash': 1,
#  'single': 2,
#  'named': 2,
#  'Kaydom': 3,
#  'year': 2,
#  'old': 2,
#  'rescued': 1,
#  'shelter': 1,
#  '3': 1,
#  'years': 2,
#  'prior': 1,
#  'logging': 1,
#  '40': 1,
#  'week': 1,
#  'running': 1,
#  'buddies': 1,
#  'surprising': 1,
#  'blazed': 1,
#  '4': 2,
#  'minutes': 1,
#  '13': 1,
#  'seconds': 1,
#  'according': 1,
#  '39': 1,
#  'Brian': 1,
#  'Duff': 1,
#  'trying': 1,
#  'knew': 1,
#  'AKC': 2,
#  'standards': 3,
#  'standard': 3,
#  'unusual': 3,
#  'word': 5,
#  'Official': 1,
#  'tell': 1,
#  'oftentimes': 2,
#  'find': 1,
#  'words': 1,
#  'perfectly': 1,
#  'fit': 1,
#  'bill': 1,
#  'include': 2,
#  'majestic': 1,
#  'calm': 1,
#  'magnificent': 1,
#  'Cane': 1,
#  'Corso': 1,
#  'trumpet': 3,
#  'describing': 1,
#  'brass': 1,
#  'instrument': 1,
#  'protruding': 1,
#  'temples': 1,
#  'pretty': 1,
#  'spot': 1,
#  'eye': 1,
#  'socket': 1,
#  'skull': 1,
#  'idea': 1,
#  'describe': 1,
#  'trait': 2,
#  'trumpets': 1,
#  'beautiful': 1,
#  'complement': 1,
#  'facial': 1,
#  'features': 1,
#  'seen': 2,
#  'nook': 1,
#  'okay': 1,
#  'confused': 1,
#  'Nooking': 1,
#  'kneads': 1,
#  'sucks': 1,
#  'stuffed': 1,
#  'toys': 1,
#  'explanation': 1,
#  'believe': 2,
#  'caused': 1,
#  'early': 1,
#  'separation': 1,
#  'mothers': 1,
#  'comfort': 1,
#  'specifically': 1,
#  'appears': 1,
#  'exclusive': 1,
#  'far': 1,
#  'President': 2,
#  'Eisenhower': 3,
#  'huge': 1,
#  'people': 3,
#  'America': 1,
#  'celebrities': 1,
#  'owned': 1,
#  'ex': 1,
#  'Dwight': 1,
#  'D.': 1,
#  'famous': 1,
#  'Heidi': 5,
#  'personality': 1,
#  'media': 1,
#  'photographers': 1,
#  'tried': 1,
#  'snap': 1,
#  'pictures': 1,
#  'Lady': 1,
#  'lunge': 1,
#  'Newspapers': 1,
#  'write': 1,
#  'sorts': 1,
#  'ridiculous': 1,
#  'stories': 3,
#  'instance': 1,
#  'reporter': 1,
#  'stated': 1,
#  'ate': 1,
#  'poached': 1,
#  'eggs': 1,
#  'toast': 1,
#  'bacon': 1,
#  'breakfast': 1,
#  'day': 1,
#  'reported': 1,
#  'meals': 1,
#  'consisted': 1,
#  'cooked': 1,
#  'ground': 1,
#  'beef': 1,
#  'mixed': 1,
#  'kibbles': 1,
#  'finally': 1,
#  'rug': 2,
#  'incident': 1,
#  'bladder': 1,
#  'failed': 1,
#  '20': 1,
#  'thousand': 1,
#  'dollar': 1,
#  'White': 1,
#  'House': 1,
#  'reception': 1,
#  'rooms': 1,
#  'moved': 1,
#  'away': 1,
#  'spotlight': 1,
#  'lived': 1,
#  'peacefully': 1,
#  'farm': 1,
#  'Pennsylvania': 1,
#  'heroic': 3,
#  'entered': 1,
#  'Animal': 2,
#  'Hall': 2,
#  'Fame': 2,
#  'saving': 1,
#  'life': 1,
#  '\xa0 ': 5,
#  'companions': 1,
#  'friends': 1,
#  'saved': 1,
#  'owners': 1,
#  '’': 1,
#  'lives': 1,
#  '\n': 4,
#  'heard': 1,
#  'Easter': 1,
#  'Sunday': 1,
#  '2007': 1,
#  'Herman': 4,
#  'Jr': 2,
#  'got': 1,
#  'middle': 1,
#  'night': 2,
#  'feeling': 1,
#  'ill': 1,
#  'decided': 1,
#  'walk': 1,
#  'house': 1,
#  'watch': 1,
#  'late': 1,
#  'television': 1,
#  'sudden': 1,
#  'collapsed': 1,
#  'struggling': 1,
#  'cry': 1,
#  'help': 1,
#  'took': 1,
#  'notice': 1,
#  'immediately': 1,
#  'ran': 1,
#  'upstairs': 1,
#  'wake': 1,
#  'wife': 2,
#  'woke': 1,
#  'found': 1,
#  'husband': 1,
#  'called': 1,
#  '911': 1,
#  '100': 1,
#  'percent': 1,
#  'blockage': 1,
#  'coronary': 1,
#  'artery': 1,
#  '50': 1,
#  'survival': 1,
#  'quick': 1,
#  'actions': 1,
#  'later': 1,
#  'inducted': 1,
#  'Iowa': 1,
#  'rightfully': 1,
#  'Cold': 2,
#  'War': 2,
#  'locating': 1,
#  'impressive': 1,
#  'qualities': 1,
#  'nose': 1,
#  'result': 1,
#  'keen': 1,
#  'smell': 1,
#  'excellent': 1,
#  'game': 1,
#  'missing': 1,
#  'fragments': 1,
#  'Dingo': 3,
#  'pointer': 1,
#  'friend': 1,
#  'crucial': 1,
#  'recovering': 1,
#  'pieces': 1,
#  'missiles': 2,
#  'scientists': 1,
#  'study': 1,
#  'failure': 1,
#  'team': 1,
#  'worked': 1,
#  'hard': 1,
#  'everyday': 1,
#  'matter': 1,
#  'weather': 1,
#  'intense': 1,
#  'heat': 1,
#  'given': 1,
#  'custom': 1,
#  'terry': 1,
#  'cloth': 1,
#  'jacket': 1,
#  'pockets': 1,
#  'hold': 1,
#  'ice': 1,
#  'cubes': 1,
#  'way': 1,
#  '96': 1,
#  'recovery': 2,
#  'program': 2,
#  'successful': 1,
#  'numerous': 1,
#  'military': 1,
#  'research': 1,
#  'agencies': 1,
#  'wanted': 1,
#  'services': 1,
#  'eventually': 1,
#  'ended': 1,
#  '1965': 1,
#  'Count': 1,
#  'history': 1,
#  'favorite': 1,
#  'miss': 1,
#  'deserve': 1,
#  'list': 1,
#  'section': 1,
#  'enjoyed': 1,
#  'video': 1,
#  'consider': 1,
#  'subscribing': 1,
#  'Smart': 1,
#  'Canine': 1,
#  'interesting': 1}

# %% [markdown]
# ### Task 7: Normalize the Frequency of Tokens

# %%
max_frequency = max(word_frequencies.values())
for word in word_frequencies.keys():
    word_frequencies[word] = word_frequencies[word]/max_frequency
word_frequencies
# Out:
# {' ': 0.009174311926605505,
#  'known': 0.03669724770642202,
#  '“': 0.1559633027522936,
#  'Gray': 0.009174311926605505,
#  'Ghost': 0.009174311926605505,
#  '”': 0.1559633027522936,
#  '\xa0\n': 1.0,
#  'sense': 0.01834862385321101,
#  'mystery': 0.009174311926605505,
#  'dogs': 0.1834862385321101,
#  'fact': 0.03669724770642202,
#  'probably': 0.009174311926605505,
#  'lot': 0.01834862385321101,
#  'things': 0.009174311926605505,
#  'know': 0.09174311926605505,
#  'Like': 0.009174311926605505,
#  'intelligent': 0.027522935779816515,
#  '\xa0\xa0 ': 0.3302752293577982,
#  'clever': 0.027522935779816515,
#  'dog': 0.1651376146788991,
#  'breeds': 0.045871559633027525,
#  'canine': 0.01834862385321101,
#  'kingdom': 0.01834862385321101,
#  'Interested': 0.009174311926605505,
#  'learning': 0.01834862385321101,
#  'behavior': 0.03669724770642202,
#  'specific': 0.009174311926605505,
#  'pockets': 0.009174311926605505,
#  'hold': 0.009174311926605505,
#  'ice': 0.009174311926605505,
#  'cubes': 0.009174311926605505,
#  'way': 0.009174311926605505,
#  '96': 0.009174311926605505,
#  'recovery': 0.01834862385321101,
#  'program': 0.01834862385321101,
#  'successful': 0.009174311926605505,
#  'numerous': 0.009174311926605505,
#  'military': 0.009174311926605505,
#  'research': 0.009174311926605505,
#  'agencies': 0.009174311926605505,
#  'wanted': 0.009174311926605505,
#  'services': 0.009174311926605505,
#  'eventually': 0.009174311926605505,
#  'ended': 0.009174311926605505,
#  '1965': 0.009174311926605505,
#  'Count': 0.009174311926605505,
#  'history': 0.009174311926605505,
#  'favorite': 0.009174311926605505,
#  'miss': 0.009174311926605505,
#  'deserve': 0.009174311926605505,
#  'list': 0.009174311926605505,
#  'section': 0.009174311926605505,
#  'enjoyed': 0.009174311926605505,
#  'video': 0.009174311926605505,
#  'consider': 0.009174311926605505,
#  'subscribing': 0.009174311926605505,
#  'Smart': 0.009174311926605505,
#  'Canine': 0.009174311926605505,
#  'interesting': 0.009174311926605505}

# %% [markdown]
# ### Task 8: Calculate Score of Sentences

# %%
sentence_tokens = [sentence for sentence in document.sents]
sentence_score = {}
for sentence in sentence_tokens:
    for word in sentence:
        if word.text.lower() in word_frequencies.keys():
            if sentence not in sentence_score.keys():
                sentence_score[sentence] = word_frequencies[word.text.lower()]
            else:
                sentence_score[sentence] += word_frequencies[word.text.lower()]
sentence_score
# Out:
# { Otherwise known as the “Gray Ghost,” there’s
#  always been a sense of mystery with these dogs.: 1.5871559633027523,
#  In fact, there’s probably a lot of
#  things you didn’t know about these dogs.: 1.348623853211009,
#  Like did you know they’re
#  one of the most intelligent   and clever dog breeds in the canine kingdom?: 1.7706422018348622,
#  Interested in learning what behavior
#  is specific to the Weimaraner breed?: 1.1559633027522938,
#  Or how Weimaraners specialized
#  in tracking down missile parts?: 1.0917431192660552,
#  If questions like these intrigue you,
#  stick around!: 1.073394495412844,
#  In today’s episode,   we’re counting down the 10 little known
#  Weimaraner facts that you didn’t know.: 1.5688073394495414,
#  But before we dive in, hit that
#  subscribe button and notification bell   for more incredible dog facts like these.: 1.660550458715596,
#  And hit that “like” button if
#  you want more Weimaraner videos.: 1.4220183486238531,
#  Number ten: Some Weimaraners
#  have “tiny horns” on their heads.: 1.385321100917431,
#  No, we’re not saying that
#  these mischievous playful   dogs are little devils - though
#  they can act like one at times.: 2.6422018348623855,
#  And we’re also not talking about the typical
#  “horns” that you see on rhinos, cattle or goats.: 1.4036697247706418,
#  Rather, there are some Weimaraners who have a tiny   flap of skin that sits on their
#  head, right above their ears.: 1.4128440366972477,
#  But not all Weimaraners have this, of course.: 0.009174311926605505,
#  It’s believed that dogs with these “little   horns” were descended from the
#  Harrasburg line of Weimaraners.: 1.9266055045871557,
#  In fact, it’s why they’re frequently
#  known as the “Harrasburg Horns.”: 1.440366972477064,
#  However, Weimaraners aren’t exactly
#  special with this set of horns.: 1.0825688073394493,
#  Similar breeds, such as the Vizsla and German
#  Shorthaired Pointer, both have these horns, too.: 1.1009174311926604,
#  So, did you check your dog?: 0.1743119266055046,
#  Do they have   the Harrasburg Horns?: 0.3761467889908257,
#  Let us
#  know in the comments below!: 1.1192660550458715,
#  Number nine: Only Weimaraners are born
#  with this unique physical characteristic.: 1.0825688073394495,
#  Dog breeds that have unique coats are
#  often born with a simple and plain coat.: 1.3394495412844036,
#  For example, the spotted Dalmatians don’t
#  actually have their spots as a newborn puppy.: 1.1100917431192658,
#  And the Blue Heeler’s unique coats are actually
#  solid white when they first arrive in this world.: 1.2201834862385321,
#  However, the Weimaraner is the opposite.: 0.009174311926605505,
#  Instead of their solid-colored coats,   Weimaraners are actually born with tiger
#  stripes that streak through their entire bodies.: 1.5596330275229358,
#  And while this looks amazing,
#  it doesn’t last very long.: 1.0366972477064218,
#  In just a few days, these tiger stripes start to
#  fade and the solid gray coats start to emerge.: 1.1926605504587158,
#  But stripes aren’t the only cool
#  thing about a Weimaraner puppy.: 1.091743119266055,
#  These dogs are also born
#  with bright, light-blue eyes.: 1.2660550458715594,
#  As the dog ages, the blue gradually
#  turns into a gray or amber color.: 1.2477064220183487,
#  Number eight: They’re nicknamed the
#  “dog with the human brain” for a reason.: 1.568807339449541,
#  Did you know that Weimaraners are some of the
#  smartest and most clever dogs in the world?: 1.36697247706422,
#  They’re so intelligent that they’ve apparently   earned themselves the nickname,
#  “dog with the human brain.”: 1.9357798165137614,
#  But just how intelligent are they?: 0.027522935779816515,
#  For obedience and working intelligence,
#  Weimaraners are the 25th smartest dogs.: 1.2660550458715598,
#  This essentially means that Weimaraners can learn
#  a new command with just 5 to 15 repetitions.: 1.1100917431192658,
#  Plus, they’re able to obey a known command, on the
#  first attempt, with a 85% or better success rate!: 1.146788990825688,
#  But what ultimately landed them the title of “dog   with a human brain” isn’t from
#  their obedience and working IQ.: 1.9449541284403669,
#  Rather, it’s from their
#  freakishly high adaptive IQ.: 1.0275229357798163,
#  This type of dog intelligence refers
#  to what the dog can learn for himself.: 1.403669724770642,
#  Weimaraners are clever dogs that are great at
#  learning from previous mistakes and experiences.: 1.275229357798165,
#  Plus, they’re some of the best
#  problem solvers in the canine kingdom.: 1.0733944954128436,
#  So does this sound like your Weimaraner? : 1.0550458715596331,
#  Let us know in the comments below!: 0.11926605504587157,
#  Number seven: They’re one of the
#  fastest dog breeds ever on land.: 1.2844036697247703,
#  Weimaraners are fast dogs.: 0.21100917431192662,
#  After all, they were bred to hunt small and
#  agile animals, such as rabbits, foxes and fowl.: 1.0825688073394493,
#  But just how fast are they?: 0.027522935779816515,
#  According to Parade.com, the Weimaraner
#  can run a remarkable 35 miles per hour!: 1.128440366972477,
#  For reference, the world’s fastest
#  horse runs about 55 miles per hour.: 1.201834862385321,
#  And the world’s fastest dog, the Greyhound,
#  can reach 45 miles per hour in full stride.: 1.3577981651376145,
#  All in all, the top speed of the Weimaraner makes
#  them one of the 10 fastest dog breeds alive.: 1.3211009174311923,
#  Number six: A Weimaraner and his owner set the
#  world record for fastest mile time in 2016.: 1.3027522935779814,
#  How do we know these dogs are some of the fastest?: 0.3302752293577982,
#  Well, we have some proof
#  to back up that statement.: 1.018348623853211,
#  In 2016, a man and his furry companion broke the   unofficial record for the “human-dog
#  mile” in Santa Barbara, California.: 1.9816513761467889,
#  This race is essentially a dog on a leash,
#  while the human and dog run a single mile.: 1.5137614678899083,
#  The dog named “Kaydom,”
#  was a 5 year old Weimaraner   who the owner rescued from
#  a shelter 3 years prior.: 3.0091743119266057,
#  Since then, they’ve been logging in
#  40 miles per week as running buddies.: 1.0825688073394493,
#  So it’s not surprising that
#  Kaydom and his owner blazed   through the mile in just 4 minutes and 13 seconds.: 1.513761467889908,
#  And according to the 39 year old owner,
#  Brian Duff, he was just trying to run as   fast as he could to keep up with
#  Kaydom through the mile-long run.: 2.6330275229357794,
#  Who knew these dogs had it in them?: 0.1926605504587156,
#  Number five: Out of all the AKC breed standards,   only the Weimaraner’s breed
#  standard has this unusual word.: 1.6422018348623855,
#  Official AKC breed standards can
#  tell you a lot about a dog breed.: 1.403669724770642,
#  And oftentimes, you’ll find words
#  that seem to perfectly fit the bill.: 1.0642201834862384,
#  For example, only 4 breed standards
#  include the word “majestic.”   : 1.8715596330275228,
#  One of which is the calm
#  and magnificent Cane Corso.: 1.018348623853211,
#  But did you know that the Weimaraner’s breed   standard is the only standard
#  to include the word “trumpet?”: 1.9724770642201834,
#  And no, they’re not describing
#  the brass instrument.: 1.0275229357798163,
#  Instead, the word “trumpet” actually refers to
#  the protruding temples on the Weimaraner’s head.: 1.495412844036697,
#  It’s pretty much the spot behind the
#  eye socket of the side of the skull.: 1.0458715596330272,
#  And while we still have no idea why the word
#  “trumpet” was used to describe this trait,   we do know that “trumpets” are a beautiful
#  complement to their facial features.: 3.2018348623853226,
#  Number four: There’s an unusual behavior
#  that’s often seen in the Weimaraner breed.: 1.1743119266055047,
#  Does your Weimaraner “nook?”: 0.3211009174311927,
#  If you don’t actually own one of these
#  dogs, then it’s okay to be confused.: 1.2477064220183485,
#  Nooking refers to the behavior where the
#  dog kneads and sucks on their stuffed toys.: 1.2660550458715596,
#  We still don’t have a full explanation for this,   but some believe that it’s caused by
#  early separation from their mothers.: 1.3944954128440366,
#  Others believe that it’s just a
#  thing Weimaraners do for comfort.: 1.055045871559633,
#  And although some say that this trait
#  is seen specifically in Weimaraners,   it appears that it’s not exclusive to this breed.: 1.4862385321100913,
#  It’s just that Weimaraners show this
#  behavior far more often than any other breed.: 1.1376146788990824,
#  Number three: US President Eisenhower’s Weimaraner
#  was a huge hit with the people of America.: 1.0642201834862386,
#  Of all the celebrities that
#  have owned a Weimaraner,   ex US President Dwight D. Eisenhower
#  may be the most famous of them all.: 2.36697247706422,
#  His Weimaraner’s name was Heidi, and she was a
#  personality that people couldn’t get enough of.: 1.036697247706422,
#  When media photographers tried to snap pictures
#  of the First Lady, Heidi would lunge at them.: 1.055045871559633,
#  Newspapers would write all sorts
#  of ridiculous stories about Heidi.: 1.055045871559633,
#  For instance, one reporter stated that
#  she ate two poached eggs on toast,   along with bacon, for breakfast every single day.: 1.440366972477064,
#  Others reported that her meals consisted of
#  cooked ground beef mixed together with kibbles.: 1.0733944954128438,
#  And finally, there was the rug
#  incident, where Heidi’s bladder   failed on a 20 thousand dollar rug in
#  one of the White House reception rooms!: 2.4678899082568813,
#  Since then, Heidi moved away
#  from the spotlight and lived   peacefully at the Eisenhower farm in Pennsylvania.: 1.3853211009174309,
#  One heroic Weimaraner entered the
#  Animal Hall of Fame for saving his owner’s life.  : 1.1743119266055044,
#  Not only are dogs great companions
#  and friends, but oftentimes they’ve   even saved their owners’ lives.: 1.642201834862385,
#  We’ve heard of these heroic   stories time and time again.: 0.48623853211009177,
#  And on Easter Sunday in 2007,   a Weimaraner named Herman Jr did it again.: 0.3944954128440367,
#  Herman’s owner got up in the middle of the night   feeling ill, so he decided to go for a walk around
#  the house and watch some late-night television.  : 1.5779816513761464,
#  In a sudden, the owner collapsed and couldn’t
#  move while struggling to cry for help.  : 1.1651376146788988,
#  Herman took notice and immediately
#  ran upstairs to wake up his wife.  : 1.1192660550458715,
#  The wife woke up and, when she
#  found her husband, called 911.  : 1.1100917431192658,
#  It was a 100-percent blockage of the coronary
#  artery, which has just a 50% survival rate.: 1.091743119266055,
#  Without the quick actions of Herman
#  Jr, his owner may not be alive today.: 1.1284403669724767,
#  Two years later, the heroic
#  Weimaraner was inducted into   Iowa’s Animal Hall of Fame, and rightfully so.: 1.4036697247706422,
#  Number one: During the Cold War, one Weimaraner
#  specialized in locating the most unusual thing.: 1.0917431192660552,
#  One of the most impressive qualities of the   Weimaraner is the nose and as a
#  result, the keen sense of smell.: 1.4036697247706422,
#  It’s why they make excellent tracking
#  dogs for small game and missing people.: 1.2844036697247705,
#  But during the Cold War, there was one Weimaraner
#  that specialized in tracking missile fragments.: 1.0917431192660552,
#  And Dingo, along with his German Shorthaired
#  pointer friend, were crucial in recovering   pieces of missiles so scientists could study
#  the success or failure of these missiles.: 2.4587155963302747,
#  The team of dogs worked hard
#  everyday no matter the weather.: 1.238532110091743,
#  In fact, in the intense heat,
#  these dogs were given a custom   terry-cloth jacket with pockets to
#  hold ice cubes as a way to cool down.: 2.6788990825688077,
#  These dogs had a 96% recovery rate,
#  and the program was so successful   that numerous military and research
#  agencies wanted the services of these dogs.: 2.8348623853211015,
#  The program eventually ended in 1965,   but Dingo and Count were the first and
#  best recovery missile dogs in history.: 1.6330275229357798,
#  So what was your favorite Weimaraner fact?: 0.045871559633027525,
#  Did
#  we miss any that deserve to be on this list?   : 1.3577981651376145,
#  Let us know in the comments section below.: 0.1651376146788991,
#  And if you enjoyed this video,   consider subscribing to The Smart Canine for the
#  most interesting stories and facts behind dogs.: 1.6330275229357798}

# %% [markdown]
# ### Task 9: Generate the Summary

# %%
select_length = int(len(sentence_tokens) * 0.3)
summary = nlargest(select_length, sentence_score, key = sentence_score.get)
final_summary = [word.text for word in summary]
summary = ' '.join(final_summary)
summary
# Out:
# 'And while we still have no idea why the word\xa0\n“trumpet” was used to describe this trait,\xa0\xa0 we do know that “trumpets” are a beautiful\xa0\ncomplement to their facial features. The dog named “Kaydom,”\xa0\nwas a 5 year old Weimaraner\xa0\xa0 who the owner rescued from\xa0\na shelter 3 years prior. These dogs had a 96% recovery rate,\xa0\nand the program was so successful\xa0\xa0 that numerous military and research\xa0\nagencies wanted the services of these dogs. In fact, in the intense heat,\xa0\nthese dogs were given a custom\xa0\xa0 terry-cloth jacket with pockets to\xa0\nhold ice cubes as a way to cool down. No, we’re not saying that\xa0\nthese mischievous playful\xa0\xa0 dogs are little devils - though\xa0\nthey can act like one at times. And according to the 39 year old owner,\xa0\nBrian Duff, he was just trying to run as\xa0\xa0 fast as he could to keep up with\xa0\nKaydom through the mile-long run. And finally, there was the rug\xa0\nincident, where Heidi’s bladder\xa0\xa0 failed on a 20 thousand dollar rug in\xa0\none of the White House reception rooms! And Dingo, along with his German Shorthaired\xa0\npointer friend, were crucial in recovering\xa0\xa0 pieces of missiles so scientists could study\xa0\nthe success or failure of these missiles. Of all the celebrities that\xa0\nhave owned a Weimaraner,\xa0\xa0 ex US President Dwight D. Eisenhower\xa0\nmay be the most famous of them all. In 2016, a man and his furry companion broke the\xa0\xa0 unofficial record for the “human-dog\xa0\nmile” in Santa Barbara, California. But did you know that the Weimaraner’s breed\xa0\xa0 standard is the only standard\xa0\nto include the word “trumpet?” But what ultimately landed them the title of “dog\xa0\xa0 with a human brain” isn’t from\xa0\ntheir obedience and working IQ. They’re so intelligent that they’ve apparently\xa0\xa0 earned themselves the nickname,\xa0\n“dog with the human brain.” It’s believed that dogs with these “little\xa0\xa0 horns” were descended from the\xa0\nHarrasburg line of Weimaraners. For example, only 4 breed standards\xa0\ninclude the word “majestic.”\xa0\xa0  Like did you know they’re\xa0\none of the most intelligent\xa0\xa0 and clever dog breeds in the canine kingdom? But before we dive in, hit that\xa0\nsubscribe button and notification bell\xa0\xa0 for more incredible dog facts like these. Number five: Out of all the AKC breed standards,\xa0\xa0 only the Weimaraner’s breed\xa0\nstandard has this unusual word. Not only are dogs great companions\xa0\nand friends, but oftentimes they’ve\xa0\xa0 even saved their owners’ lives.\n The program eventually ended in 1965,\xa0\xa0 but Dingo and Count were the first and\xa0\nbest recovery missile dogs in history. And if you enjoyed this video,\xa0\xa0 consider subscribing to The Smart Canine for the\xa0\nmost interesting stories and facts behind dogs.  Otherwise known as the “Gray Ghost,” there’s\xa0\nalways been a sense of mystery with these dogs. Herman’s owner got up in the middle of the night\xa0\xa0 feeling ill, so he decided to go for a walk around\xa0\nthe house and watch some late-night television.\xa0  In today’s episode,\xa0\xa0 we’re counting down the 10 little known\xa0\nWeimaraner facts that you didn’t know. Number eight: They’re nicknamed the\xa0\n“dog with the human brain” for a reason. Instead of their solid-colored coats,\xa0\xa0 Weimaraners are actually born with tiger\xa0\nstripes that streak through their entire bodies. This race is essentially a dog on a leash,\xa0\nwhile the human and dog run a single mile. So it’s not surprising that\xa0\nKaydom and his owner blazed\xa0\xa0 through the mile in just 4 minutes and 13 seconds. Instead, the word “trumpet” actually refers to\xa0\nthe protruding temples on the Weimaraner’s head. And although some say that this trait\xa0\nis seen specifically in Weimaraners,\xa0\xa0 it appears that it’s not exclusive to this breed. In fact, it’s why they’re frequently\xa0\nknown as the “Harrasburg Horns.” For  ...
